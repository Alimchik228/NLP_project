# %% [markdown]
# # Инструменты для работы с языком

# %% [markdown]
# ## Задача: классификация твитов по тональности
#
# У нас есть датасет из твитов, про каждый указано, как он эмоционально окрашен: положительно или отрицательно. Задача: предсказывать эмоциональную окраску.
#
# Скачиваем куски датасета ([источник](http://study.mokoron.com/)): [положительные](https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv?dl=0), [отрицательные](https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv).

# %%
# если у вас линукс / мак / collab или ещё какая-то среда, в которой работает wget, можно так:
# !wget https://www.dropbox.com/s/fnpq3z4bcnoktiv/positive.csv
# !wget https://www.dropbox.com/s/r6u59ljhhjdg6j0/negative.csv
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import *
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
# считываем данные и заполняем общий датасет
positive = pd.read_csv('positive.csv', sep=';', usecols=[3], names=['text'])
positive['label'] = ['positive'] * len(positive)
negative = pd.read_csv('negative.csv', sep=';', usecols=[3], names=['text'])
negative['label'] = ['negative'] * len(negative)
df = positive.append(negative)

# %%
df.tail()
# Out:
#                                                      text     label
# 111918  Но не каждый хочет что то исправлять:( http://...  negative
# 111919  скучаю так :-( только @taaannyaaa вправляет мо...  negative
# 111920          Вот и в школу, в говно это идти уже надо(  negative
# 111921  RT @_Them__: @LisaBeroud Тауриэль, не грусти :...  negative
# 111922  Такси везет меня на работу. Раздумываю приплат...  negative

# %%
x_train, x_test, y_train, y_test = train_test_split(df.text, df.label)

# %% [markdown]
# ## Baseline: классификация необработанных n-грамм
#
# ### Векторизаторы

# %%
from sklearn.linear_model import LogisticRegression # можно заменить на любимый классификатор
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Что такое n-граммы:

# %%
from nltk import ngrams

# %%
sent = 'Если б мне платили каждый раз'.split()
list(ngrams(sent, 1)) # униграммы
# Out:
# [('Если',), ('б',), ('мне',), ('платили',), ('каждый',), ('раз',)]

# %%
list(ngrams(sent, 2)) # биграммы
# Out:
# [('Если', 'б'),
#  ('б', 'мне'),
#  ('мне', 'платили'),
#  ('платили', 'каждый'),
#  ('каждый', 'раз')]

# %%
list(ngrams(sent, 3)) # триграммы
# Out:
# [('Если', 'б', 'мне'),
#  ('б', 'мне', 'платили'),
#  ('мне', 'платили', 'каждый'),
#  ('платили', 'каждый', 'раз')]

# %%
list(ngrams(sent, 5)) # ... пентаграммы?
# Out:
# [('Если', 'б', 'мне', 'платили', 'каждый'),
#  ('б', 'мне', 'платили', 'каждый', 'раз')]

# %% [markdown]
# Самый простой способ извлечь фичи из текстовых данных -- векторизаторы: `CountVectorizer` и `TfidfVectorizer`
#
# Объект `CountVectorizer` делает простую вещь:
# * строит для каждого документа (каждой пришедшей ему строки) вектор размерности `n`, где `n` -- количество слов или n-грам во всём корпусе
# * заполняет каждый i-тый элемент количеством вхождений слова в данный документ

# %%
vec = CountVectorizer(ngram_range=(1, 1))
bow = vec.fit_transform(x_train) # bow -- bag of words (мешок слов)

# %%
bow
# Out:
# <170125x243650 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1849642 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ngram_range отвечает за то, какие n-граммы мы используем в качестве фичей:<br/>
# ngram_range=(1, 1) -- униграммы<br/>
# ngram_range=(3, 3) -- триграммы<br/>
# ngram_range=(1, 3) -- униграммы, биграммы и триграммы.
#
# В vec.vocabulary_ лежит словарь: мэппинг слов к их индексам:

# %%
list(vec.vocabulary_.items())[:10]
# Out:
# [('кто', 150098),
#  ('сказал', 209712),
#  ('что', 237733),
#  ('особенных', 174810),
#  ('дат', 123503),
#  ('больше', 107340),
#  ('не', 165294),
#  ('будет', 108576),
#  ('13', 835),
#  ('12', 756)]

# %%
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=42)

# %%
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.76      0.76     27873
#     positive       0.77      0.76      0.77     28836
#
#     accuracy                           0.76     56709
#    macro avg       0.76      0.76      0.76     56709
# weighted avg       0.76      0.76      0.76     56709

# %% [markdown]
# Попробуем сделать то же самое для триграмм:

# %%
vec = CountVectorizer(ngram_range=(3, 3))
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.47      0.72      0.57     18265
#     positive       0.82      0.61      0.70     38444
#
#     accuracy                           0.65     56709
#    macro avg       0.64      0.67      0.63     56709
# weighted avg       0.71      0.65      0.66     56709

# %% [markdown]
# (как вы думаете, почему в результатах теперь такой разброс по сравнению с униграммами?)

# %% [markdown]
# ## TF-IDF векторизация

# %% [markdown]
# `TfidfVectorizer` делает то же, что и `CountVectorizer`, но в качестве значений – tf-idf каждого слова.
#
# Как считается tf-idf:
#
# TF (term frequency) – относительная частотность слова в документе:
# $$ TF(t,d) = \frac{n_t}{\sum_k n_k} $$
#
# `t` -- слово (term), `d` -- документ, $n_t$ -- количество вхождений слова, $n_k$ -- количество вхождений остальных слов
#
# IDF (inverse document frequency) – обратная частота документов, в которых есть это слово:
# $$ IDF(t, D) = \mbox{log} \frac{|D|}{|{d : t \in d}|} $$
#
# `t` -- слово (term), `D` -- коллекция документов
#
# Перемножаем их:
# $$TFIDF_(t,d,D) = TF(t,d) \times IDF(i, D)$$
#
# Сакральный смысл – если слово часто встречается в одном документе, но в целом по корпусу встречается в небольшом
# количестве документов, у него высокий TF-IDF.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vec = TfidfVectorizer(ngram_range=(1, 1))
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.73      0.77      0.75     26665
#     positive       0.78      0.75      0.76     30044
#
#     accuracy                           0.76     56709
#    macro avg       0.76      0.76      0.76     56709
# weighted avg       0.76      0.76      0.76     56709

# %% [markdown]
# В этот раз получилось хуже :( Вернёмся к `CountVectorizer`.

# %% [markdown]
# ## PMI

# %% [markdown]
# Можно оценить взаимосвязь слов в корпусе и понять, какие биграммы наиболее часто встречаются в тексте. Для этого можно использовать метрику PMI (Pointwise Mutual Information) - поточечная взаимная информация. Метрика PMI для двух слов вычисляется по формуле:
#
# $$pmi(x; y) = log \frac{p(x,y)}{p(x)p(y)} $$
#
# Здесь p(y|x) - вероятность встретить слово $y$ после $x$, $p(y)$ - вероятность встретить слово $y$.

# %% [markdown]
# Оценим важность биграмм в нашем обучающем корпусе.

# %%
import nltk
from nltk import collocations 
nltk.download('genesis')

print(type(nltk.corpus.genesis.words('english-web.txt')))
bigram_measures = collocations.BigramAssocMeasures()
# bigram_finder.apply_freq_filter(5)
bigram_finder = collocations.BigramCollocationFinder.from_documents([nltk.word_tokenize(x) for x in x_train])
bigrams = bigram_finder.nbest(bigram_measures.pmi, 100)
print(bigrams)
# Out:
# [nltk_data] Downloading package genesis to
# [nltk_data]     C:\Users\alimc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\genesis.zip.
# <class 'nltk.corpus.reader.util.StreamBackedCorpusView'>
# [('+1239', '728'), ('+375447167151', 'звоги'), ('+погода', 'крутая='), (',4', 'запирайте'), (',Дела', 'рез'), ('-/////', 'прбрм-прбрм'), ('-163', '-КРАСНЫЙ'), ('-165', '-СИНИЙ'), ('-53', 'dBm'), ('-800', 'нахууй'), ('-АХАХАХАХ', 'ЮБКУ'), ('-АХАХАХАХХАХАХАХАХАХХА', '-АХАХАХХАХАХАХАХАХ'), ('-Айгуль', 'Маратовна'), ('-Алина', '-Синие'), ('-Аха', 'спетросянил'), ('-ВАХАХАХА', 'СТИПЕНДИЯ'), ('-ВСЕМ', 'СПОКОЙНЫХ'), ('-Вам', 'завернуть'), ('-Весело', 'кншн:3'), ('-Вообще-то', '3.Я'), ('-Восьмигрудый', 'трипи'), ('-Время', 'эмокора'), ('-Выздоравливай', 'педрилк'), ('-Д-Д-Д-Д-Д-Д-ДРОП', 'ЗЭ'), ('-ДЕТЕЙ', 'НАКРЫЛО'), ('-ДОВАЙТИ', 'АЛДСКУЛ'), ('-Дирол', 'Сенсес'), ('-Домашка', '-кл.час'), ('-ЗАШЛА', 'ОДЕЛА'), ('-Защитано', '-ес'), ('-Зелено-карие', '-Киллджой'), ('-КРАСНЫЙ', '-ЧЕРНЫЕ'), ('-Керем', 'севгили'), ('-Киллджой', '-Котик'), ('-Корнейчук', 'затроллила'), ('-Маладец', '-Лол'), ('-Мамаааа', 'поправь'), ('-НУ', 'МАМ'), ('-ОЗВУЧИВАТЕЛЬ', 'МУЛЬТИКОВ'), ('-Обойдутся', '-Иногда'), ('-Олесь', '-Пошёл'), ('-Песня', 'грусная='), ('-Плохое', 'пищеварение'), ('-Под', 'Киевом'), ('-Поэзия', 'заключает'), ('-ПриФетиГг', 'СолНыСко='), ('-Рыбу', 'соленую'), ('-СИНИЙ', '-БЕЛЫЕ'), ('-Серые', '-НЕМЕЦКИЕ'), ('-Танцы', '-Хорошие'), ('-Трахався', '-Іди'), ('-Филл', '-познакомились'), ('-ШАПКА', '-ФОН'), ('-Юлия', 'Зазулина'), ('-Я.банан', '-ахх'), ('-анал', '-абстиненция'), ('-анатолий', 'николаевич'), ('-аниме', '-15-16'), ('-бляя', 'хммммммм'), ('-водичку', 'лью'), ('-возвышенная', 'местность'), ('-г', 'үзээ'), ('-гoop', 'Хакүхо'), ('-говорит', 'одноногий'), ('-дерьмо', 'редкосное'), ('-иногда', '.Ностальгирую'), ('-киллджой', '-шатенка'), ('-классный', 'ответ.в'), ('-крутенько', '-выйду'), ('-купи', 'куру'), ('-кучи', 'мутики'), ('-ладно', '-АХАХАХАХХАХАХАХАХАХХА'), ('-ложусь', 'спать-темно'), ('-любому', 'умрёшь'), ('-мега', 'шизофреничная'), ('-напиши', '-нит'), ('-наш', 'класс^^'), ('-новый', 'молодежный'), ('-пиздишь', '-отвечаю'), ('-пиши', 'Ненси'), ('-попробуй', 'помедитировать'), ('-раз', 'плёткой'), ('-распускаю', 'волосы-'), ('-руу', 'орох'), ('-рүү', 'мэншндсэн'), ('-скоро', 'зароются'), ('-случайные', 'вопросы-'), ('-спрашивает', 'жена.-У'), ('-стакану', 'сметаны'), ('-столько', 'бабосов'), ('-такое', 'ВЧ-8='), ('-твиты', '+био'), ('-указуказуказуказуа', '-материшся'), ('-хаски', '-розовое'), ('-хуи', 'сосешь'), ('-цвета', 'Магнита'), ('-цитирую', 'гастролога'), ('-цытата', 'Шимы'), ('-черные', '-аниме'), ('-что-то', 'неописуемое')]

# %% [markdown]
# Можно рассмотреть другие метрики оценки важности биграмм, например, метрику правдоподобия (подробнее про вычисление метрики можно посмотреть [здесь (пункт 5.3.4)](http://www.corpus.unam.mx/cursoenah/ManningSchutze_1999_FoundationsofStatisticalNaturalLanguageProcessing.pdf):

# %%
bigrams = bigram_finder.nbest(bigram_measures.likelihood_ratio, 100)
print(bigrams)
# Out:
# [('(', '('), ('RT', '@'), (')', ')'), ('http', ':'), ('!', '!'), (':', 'D'), ('у', 'меня'), (':', '('), (',', 'а'), (',', 'что'), (',', 'но'), (')', 'http'), ('*', '*'), ('у', 'нас'), (':', ')'), ('(', ','), ('не', 'могу'), (':', '-'), (',', '('), (',', ')'), ('?', '?'), (')', ','), (',', ':'), (',', ','), ('@', '('), ('(', ':'), (':', ','), ('&', 'lt'), ('@', ','), ('со', 'мной'), ('@', ':'), ('(', '@'), (':', ':'), ('новый', 'год'), (';', ')'), ('gt', ';'), ('не', 'знаю'), (',', '@'), (':', '*'), (')', ':'), ('@', '@'), ('а', 'я'), ('потому', 'что'), ('lt', ';'), (',', 'когда'), ('У', 'меня'), ('сих', 'пор'), ('&', 'gt'), ('у', 'тебя'), (';', '('), ('все', 'равно'), ('с', 'тобой'), (',', 'как'), ('в', 'школу'), ('(', 'http'), (')', '@'), ('&', 'amp'), ('Доброе', 'утро'), ('Как', 'же'), ('ничего', 'не'), ('-', ')'), (',', 'я'), ('я', 'не'), (':', 'DD'), ('не', '('), ('самом', 'деле'), ('--', '--'), ('не', ')'), (',', 'чтобы'), ('как', 'же'), ('(', '!'), ('amp', ';'), ('до', 'сих'), ('что', 'я'), (',', '!'), ('.', 'А'), ('об', 'этом'), ('D', 'http'), ('не', ':'), ('с', 'кем'), ('=', ')'), ('и', '('), ('!', ','), ('никто', 'не'), (':', '!'), ('а', 'потом'), ('?', '—'), (':', '|'), ('и', ')'), ('никогда', 'не'), (',', '.'), ('.', ','), ('#', 'євромайдан'), ('@', 'не'), ('не', '@'), ('.', 'Но'), ('Новый', 'Год'), (':', '.'), ('на', 'улице'), ('в', 'школе')]

# %% [markdown]
# Как можно заметить, немаловажную роль в текстах занимает пунктуация.

# %% [markdown]
# ## Стоп-слова и пунктуация
#
# *Стоп-слова* -- это слова, которые часто встречаются практически в любом тексте и ничего интересного не говорят о конретном документе, то есть играют роль шума. Поэтому их принято убирать. По той же причине убирают и пунктуацию.

# %%
# у вас здесь, вероятно, выскочит ошибка и надо будет загрузить стоп слова (в тексте ошибки написано, как)
from nltk.corpus import stopwords
nltk.download('stopwords')
print(stopwords.words('russian'))
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\alimc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from string import punctuation
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
noise = stopwords.words('russian') + list(punctuation)

# %% [markdown]
# В векторизаторах за стоп-слова, логичным образом, отвечает аргумент `stop_words`.

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize, stop_words=noise)
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['``'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
#               precision    recall  f1-score   support
#
#     negative       0.80      0.76      0.78     29367
#     positive       0.75      0.79      0.77     27342
#
#     accuracy                           0.78     56709
#    macro avg       0.78      0.78      0.78     56709
# weighted avg       0.78      0.78      0.78     56709

# %% [markdown]
# Получилось чууть лучше. Что ещё можно сделать?

# %% [markdown]
# ## Лемматизация
#
# Лемматизация – это сведение разных форм одного слова к начальной форме – *лемме*. Почему это хорошо?
# * Во-первых, мы хотим рассматривать как отдельную фичу каждое *слово*, а не каждую его отдельную форму.
# * Во-вторых, некоторые стоп-слова стоят только в начальной форме, и без лематизации выкидываем мы только её.
#
# Для русского есть два хороших лемматизатора: mystem и pymorphy:
#
# ### [Mystem](https://tech.yandex.ru/mystem/)
# Как с ним работать:
# * можно скачать mystem и запускать [из терминала с разными параметрами](https://tech.yandex.ru/mystem/doc/)
# * [pymystem3](https://pythonhosted.org/pymystem3/pymystem3.html) - обертка для питона, работает медленнее, но это удобно

# %%
# !wget http://download.cdn.yandex.net/mystem/mystem-3.0-linux3.1-64bit.tar.gz
# !tar -xvf mystem-3.0-linux3.1-64bit.tar.gz
# !cp mystem /bin
# Out:
# "wget" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.
# tar: Error opening archive: Failed to open 'mystem-3.0-linux3.1-64bit.tar.gz'
# "cp" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %%
# !pip install pymystem3
# Out:
# Collecting pymystem3
#   Downloading pymystem3-0.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests in c:\users\alimc\anaconda3\lib\site-packages (from pymystem3) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alimc\anaconda3\lib\site-packages (from requests->pymystem3) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alimc\anaconda3\lib\site-packages (from requests->pymystem3) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\alimc\anaconda3\lib\site-packages (from requests->pymystem3) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alimc\anaconda3\lib\site-packages (from requests->pymystem3) (3.2)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymystem3 import Mystem
mystem_analyzer = Mystem()
# Out:
# Installing mystem to C:\Users\alimc/.local/bin\mystem.exe from http://download.cdn.yandex.net/mystem/mystem-3.1-win-64bit.zip

# %% [markdown]
# Мы инициализировали Mystem c дефолтными параметрами. А вообще параметры есть такие:
# * mystem_bin - путь к `mystem`, если их несколько
# * grammar_info - нужна ли грамматическая информация или только леммы (по дефолту нужна)
# * disambiguation - нужно ли снятие омонимии - дизамбигуация (по дефолту нужна)
# * entire_input - нужно ли сохранять в выводе все (пробелы всякие, например), или можно выкинуть (по дефолту оставляется все)
#
# Методы Mystem принимают строку, токенизатор вшит внутри. Можно, конечно, и пословно анализировать, но тогда он не сможет учитывать контекст.
#
# Можно просто лемматизировать текст:

# %%
print(mystem_analyzer.lemmatize(example))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14044/858324376.py in <module>
# ----> 1 print(mystem_analyzer.lemmatize(example))
#
# NameError: name 'example' is not defined

# %% [markdown]
# А можно получить грамматическую информацию:

# %%
mystem_analyzer.analyze(example)
# Out:
# [{'analysis': [{'gr': 'CONJ=', 'lex': 'но', 'wt': 0.9998906255}],
#   'text': 'Но'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'PART=', 'lex': 'не', 'wt': 1}], 'text': 'не'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'APRO=(вин,ед,муж,неод|им,ед,муж)',
#     'lex': 'каждый',
#     'wt': 0.9985975623}],
#   'text': 'каждый'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,несов,пе=непрош,ед,изъяв,3-л',
#     'lex': 'хотеть',
#     'wt': 1}],
#   'text': 'хочет'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'SPRO,ед,сред,неод=(вин|им)', 'lex': 'что-то', 'wt': 1}],
#   'text': 'что-то'},
#  {'text': ' '},
#  {'analysis': [{'gr': 'V,пе=инф,несов', 'lex': 'исправлять', 'wt': 1}],
#   'text': 'исправлять'},
#  {'text': ':(\n'}]

# %% [markdown]
# Давайте терепь используем лемматизатор майстема в качестве токенизатора.

# %%
import re
def my_preproc(text):
    text = re.sub('[{}]'.format(punctuation), '', text)
    text = mystem_analyzer.lemmatize(text)
    return [word for word in text if word not in stopwords.words('russian') + [' ', '\n']]

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=my_preproc)
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14044/1341883163.py in <module>
#       1 vec = CountVectorizer(ngram_range=(1, 1), tokenizer=my_preproc)
# ----> 2 bow = vec.fit_transform(x_train)
#       3 clf = LogisticRegression(random_state=42)
#       4 clf.fit(bow, y_train)
#       5 pred = clf.predict(vec.transform(x_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1200         max_features = self.max_features
#    1201
# -> 1202         vocabulary, X = self._count_vocab(raw_documents,
#    1203                                           self.fixed_vocabulary_)
#    1204
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1112         for doc in raw_documents:
#    1113             feature_counter = {}
# -> 1114             for feature in analyze(doc):
#    1115                 try:
#    1116                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
# --> 106             doc = tokenizer(doc)
#     107         if ngrams is not None:
#     108             if stop_words is not None:
#
# ~\AppData\Local\Temp/ipykernel_14044/1478339074.py in my_preproc(text)
#       2 def my_preproc(text):
#       3     text = re.sub('[{}]'.format(punctuation), '', text)
# ----> 4     text = mystem_analyzer.lemmatize(text)
#       5     return [word for word in text if word not in stopwords.words('russian') + [' ', '\n']]
#
# ~\Anaconda3\lib\site-packages\pymystem3\mystem.py in lemmatize(self, text)
#     263         need_encode = (sys.version_info[0] < 3 and isinstance(text, str))
#     264
# --> 265         infos = self.analyze(text)
#     266         lemmas = list(filter(None, map(self._get_lemma, infos)))
#     267
#
# ~\Anaconda3\lib\site-packages\pymystem3\mystem.py in analyze(self, text)
#     248         result = []
#     249         for line in text.splitlines():
# --> 250             result.extend(self._analyze_impl(line))
#     251         return result
#     252
#
# ~\Anaconda3\lib\site-packages\pymystem3\mystem.py in _analyze_impl(self, text)
#     308                 self._start_mystem()
#     309
# --> 310             self._procin.write(text)
#     311             self._procin.write(_NL)
#     312
#
# ValueError: I/O operation on closed file

# %% [markdown]
# ### [Pymorphy](http://pymorphy2.readthedocs.io/en/latest/)
# Это модуль на питоне, довольно быстрый и с кучей функций.

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 1.9 MB/s
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2) (0.6.2)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
#      |████████████████████████████████| 8.2 MB 10.7 MB/s
# Installing collected packages: pymorphy2-dicts-ru, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %%
from pymorphy2 import MorphAnalyzer
pymorphy2_analyzer = MorphAnalyzer()

# %% [markdown]
# pymorphy2 работает с отдельными словами. Если дать ему на вход предложение - он его просто не лемматизирует, т.к. не понимает

# %%
ana = pymorphy2_analyzer.parse(sent[3])
ana
# Out:
# [Parse(word='платили', tag=OpencorporaTag('VERB,impf,tran plur,past,indc'), normal_form='платить', score=1.0, methods_stack=((DictionaryAnalyzer(), 'платили', 2472, 10),))]

# %%
ana[0].normal_form
# Out:
# 'платить'

# %% [markdown]
# ### [Natasha](https://github.com/natasha/)
#
# В библиотеке natasha реализовано множество полезных библиотек для русского языка: разбиение на токены и предложения, русскоязычные word embeddings, морфологический, синтаксический анализ, лемматизация, извлечение именованных сущностей и т.д. Модуль библиотеки Razdel, основанный на правилах, предназначен для разбиения текста на токены и предложения.

# %%
# !pip install razdel
# Out:
# Collecting razdel
#   Downloading razdel-0.5.0-py3-none-any.whl (21 kB)
# Installing collected packages: razdel
# Successfully installed razdel-0.5.0
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from razdel import tokenize

tokens = list(tokenize('Кружка-термос на 0.5л (50/64 см³, 516;...)'))
tokens
# Out:
# [Substring(0, 13, 'Кружка-термос'),
#  Substring(14, 16, 'на'),
#  Substring(17, 20, '0.5'),
#  Substring(20, 21, 'л'),
#  Substring(22, 23, '('),
#  Substring(23, 28, '50/64'),
#  Substring(29, 32, 'см³'),
#  Substring(32, 33, ','),
#  Substring(34, 37, '516'),
#  Substring(37, 38, ';'),
#  Substring(38, 41, '...'),
#  Substring(41, 42, ')')]

# %%
[_.text for _ in tokens]
# Out:
# ['Кружка-термос',
#  'на',
#  '0.5',
#  'л',
#  '(',
#  '50/64',
#  'см³',
#  ',',
#  '516',
#  ';',
#  '...',
#  ')']

# %%
# !pip install natasha
# Out:
# Collecting natasha
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Downloading natasha-1.6.0-py3-none-any.whl (34.4 MB)
#      -------------------------------------- 34.4/34.4 MB 488.4 kB/s eta 0:00:00
# Requirement already satisfied: pymorphy2 in c:\users\alimc\anaconda3\lib\site-packages (from natasha) (0.9.1)
# Requirement already satisfied: razdel>=0.5.0 in c:\users\alimc\anaconda3\lib\site-packages (from natasha) (0.5.0)
# Collecting navec>=0.9.0 (from natasha)
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Collecting slovnet>=0.6.0 (from natasha)
#   Downloading slovnet-0.6.0-py3-none-any.whl (46 kB)
#      -------------------------------------- 46.7/46.7 kB 466.9 kB/s eta 0:00:00
# Collecting yargy>=0.16.0 (from natasha)
#   Downloading yargy-0.16.0-py3-none-any.whl (33 kB)
# Collecting ipymarkup>=0.8.0 (from natasha)
#   Downloading ipymarkup-0.9.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: intervaltree>=3 in c:\users\alimc\anaconda3\lib\site-packages (from ipymarkup>=0.8.0->natasha) (3.1.0)
# Requirement already satisfied: numpy in c:\users\alimc\anaconda3\lib\site-packages (from navec>=0.9.0->natasha) (1.22.4)
# Requirement already satisfied: dawg-python>=0.7.1 in c:\users\alimc\anaconda3\lib\site-packages (from pymorphy2->natasha) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in c:\users\alimc\anaconda3\lib\site-packages (from pymorphy2->natasha) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in c:\users\alimc\anaconda3\lib\site-packages (from pymorphy2->natasha) (0.6.2)
# Requirement already satisfied: sortedcontainers<3.0,>=2.0 in c:\users\alimc\anaconda3\lib\site-packages (from intervaltree>=3->ipymarkup>=0.8.0->natasha) (2.4.0)
# Installing collected packages: navec, yargy, slovnet, ipymarkup, natasha
# Successfully installed ipymarkup-0.9.0 natasha-1.6.0 navec-0.10.0 slovnet-0.6.0 yargy-0.16.0

# %% [markdown]
# С помощью библиотеки natasha можно также лемматизировать тексты.

# %%
from natasha import Doc, MorphVocab, Segmenter, NewsEmbedding, NewsMorphTagger

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)

def natasha_lemmatize(text):
  doc = Doc(text)
  doc.segment(segmenter)
  doc.tag_morph(morph_tagger)
  for token in doc.tokens:
    token.lemmatize(morph_vocab)
  return {_.text: _.lemma for _ in doc.tokens}

# %%
text = 'Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Рады. Парламентарии уверены, что признание Бандеры национальным героем поможет в борьбе с подрывной деятельностью против Украины в информационном поле, а также остановит «распространение мифов, созданных российской пропагандой». Степан Бандера (1909-1959) был одним из лидеров Организации украинских националистов, выступающей за создание независимого государства на территориях с украиноязычным населением. В 2010 году в период президентства Виктора Ющенко Бандера был посмертно признан Героем Украины, однако впоследствии это решение было отменено судом. '

natasha_lemmatize(text)
# Out:
# {'Посол': 'посол',
#  'Израиля': 'израиль',
#  'на': 'на',
#  'Украине': 'украина',
#  'Йоэль': 'йоэль',
#  'Лион': 'лион',
#  'признался': 'признаться',
#  ',': ',',
#  'что': 'что',
#  'пришел': 'прийти',
#  'в': 'в',
#  'шок': 'шок',
#  'узнав': 'узнать',
#  'о': 'о',
#  'решении': 'решение',
#  'властей': 'власть',
#  'Львовской': 'львовский',
#  'области': 'область',
#  'объявить': 'объявить',
#  '2019': '2019',
#  'год': 'год',
#  'годом': 'год',
#  'лидера': 'лидер',
#  'запрещенной': 'запретить',
#  'России': 'россия',
#  'Организации': 'организация',
#  'украинских': 'украинский',
#  'националистов': 'националист',
#  '(': '(',
#  'ОУН': 'оун',
#  ')': ')',
#  'Степана': 'степан',
#  'Бандеры': 'бандера',
#  '.': '.',
#  'Свое': 'свой',
#  'заявление': 'заявление',
#  'он': 'он',
#  'разместил': 'разместить',
#  'Twitter': 'twitter',
#  '«': '«',
#  'Я': 'я',
#  'не': 'не',
#  'могу': 'мочь',
#  'понять': 'понять',
#  'как': 'как',
#  'прославление': 'прославление',
#  'тех': 'тот',
#  'кто': 'кто',
#  'непосредственно': 'непосредственно',
#  'принимал': 'принимать',
#  'участие': 'участие',
#  'ужасных': 'ужасный',
#  'антисемитских': 'антисемитский',
#  'преступлениях': 'преступление',
#  'помогает': 'помогать',
#  'бороться': 'бороться',
#  'с': 'с',
#  'антисемитизмом': 'антисемитизм',
#  'и': 'и',
#  'ксенофобией': 'ксенофобия',
#  'Украина': 'украина',
#  'должна': 'должный',
#  'забывать': 'забывать',
#  'совершенных': 'совершить',
#  'против': 'против',
#  'евреев': 'еврей',
#  'никоим': 'никой',
#  'образом': 'образ',
#  'отмечать': 'отмечать',
#  'их': 'они',
#  'через': 'через',
#  'почитание': 'почитание',
#  'исполнителей': 'исполнитель',
#  '»': '»',
#  '—': '—',
#  'написал': 'написать',
#  'дипломат': 'дипломат',
#  '11': '11',
#  'декабря': 'декабрь',
#  'Львовский': 'львовский',
#  'областной': 'областной',
#  'совет': 'совет',
#  'принял': 'принять',
#  'решение': 'решение',
#  'провозгласить': 'провозгласить',
#  'регионе': 'регион',
#  'связи': 'связь',
#  'празднованием': 'празднование',
#  '110-летия': '110-летие',
#  'со': 'с',
#  'дня': 'день',
#  'рождения': 'рождение',
#  'Бандера': 'бандера',
#  'родился': 'родиться',
#  '1': '1',
#  'января': 'январь',
#  '1909': '1909',
#  'года': 'год',
#  'В': 'в',
#  'июле': 'июль',
#  'аналогичное': 'аналогичный',
#  'Житомирский': 'житомирский',
#  'начале': 'начало',
#  'месяца': 'месяц',
#  'предложением': 'предложение',
#  'к': 'к',
#  'президенту': 'президент',
#  'страны': 'страна',
#  'Петру': 'петр',
#  'Порошенко': 'порошенко',
#  'вернуть': 'вернуть',
#  'Бандере': 'бандера',
#  'звание': 'звание',
#  'Героя': 'герой',
#  'Украины': 'украина',
#  'обратились': 'обратиться',
#  'депутаты': 'депутат',
#  'Верховной': 'верховный',
#  'Рады': 'рада',
#  'Парламентарии': 'парламентарий',
#  'уверены': 'уверить',
#  'признание': 'признание',
#  'национальным': 'национальный',
#  'героем': 'герой',
#  'поможет': 'помочь',
#  'борьбе': 'борьба',
#  'подрывной': 'подрывной',
#  'деятельностью': 'деятельность',
#  'информационном': 'информационный',
#  'поле': 'поле',
#  'а': 'а',
#  'также': 'также',
#  'остановит': 'остановить',
#  'распространение': 'распространение',
#  'мифов': 'миф',
#  'созданных': 'создать',
#  'российской': 'российский',
#  'пропагандой': 'пропаганда',
#  'Степан': 'степан',
#  '1909-1959': '1909-1959',
#  'был': 'быть',
#  'одним': 'один',
#  'из': 'из',
#  'лидеров': 'лидер',
#  'выступающей': 'выступать',
#  'за': 'за',
#  'создание': 'создание',
#  'независимого': 'независимый',
#  'государства': 'государство',
#  'территориях': 'территория',
#  'украиноязычным': 'украиноязычный',
#  'населением': 'население',
#  '2010': '2010',
#  'году': 'год',
#  'период': 'период',
#  'президентства': 'президентство',
#  'Виктора': 'виктор',
#  'Ющенко': 'ющенко',
#  'посмертно': 'посмертно',
#  'признан': 'признать',
#  'Героем': 'герой',
#  'однако': 'однако',
#  'впоследствии': 'впоследствии',
#  'это': 'это',
#  'было': 'быть',
#  'отменено': 'отменить',
#  'судом': 'суд'}

# %% [markdown]
# ### mystem vs. pymorphy vs. natasha
#
# 1) *Мы надеемся, что вы пользуетесь линуксом*, но mystem работает невероятно медленно под windows на больших текстах.
#
# 2) *Снятие омонимии*. Mystem умеет снимать омонимию по контексту (хотя не всегда преуспевает), pymorphy2 берет на вход одно слово и соответственно вообще не умеет дизамбигуировать по контексту, natasha тоже с этим тоже не справляется успешно:

# %%
homonym1 = 'За время обучения я прослушал больше сорока курсов.'
homonym2 = 'Сорока своровала блестящее украшение со стола.'

# %%
mystem_analyzer = Mystem() # инициализирую объект с дефолтными параметрами

print(mystem_analyzer.analyze(homonym1)[-5])
print(mystem_analyzer.analyze(homonym2)[0])
# Out:
# {'analysis': [{'lex': 'сорок', 'wt': 0.8710292664, 'gr': 'NUM=(пр|дат|род|твор)'}], 'text': 'сорока'}
# {'analysis': [{'lex': 'сорока', 'wt': 0.1210970041, 'gr': 'S,жен,од=им,ед'}], 'text': 'Сорока'}

# %%
print(natasha_lemmatize(homonym1))
# Out:
# {'За': 'за', 'время': 'время', 'обучения': 'обучение', 'я': 'я', 'прослушал': 'прослушать', 'больше': 'большой', 'сорока': 'сорок', 'курсов': 'курс', '.': '.'}

# %%
print(natasha_lemmatize(homonym2))
# Out:
# {'Сорока': 'сорок', 'своровала': 'своровать', 'блестящее': 'блестящий', 'украшение': 'украшение', 'со': 'с', 'стола': 'стол', '.': '.'}

# %% [markdown]
# ## Словарь, закон Ципфа и закон Хипса

# %% [markdown]
# Закон Ципфа -- эмпирическая закономерность: если все слова корпуса текста упорядочить по убыванию частоты их использования, то частота n-го слова в таком списке окажется приблизительно обратно пропорциональной его порядковому номеру n. Иными словами, частотность слов убывает очень быстро.

# %%
from collections import Counter

# %%
from nltk.tokenize import word_tokenize
corpus = [token for tweet in df.text for token in word_tokenize(tweet) if token not in punctuation]
print(len(corpus))
corpus[:10]
# Out:
# 2870536
# ['first_timee', 'хоть', 'я', 'и', 'школота', 'но', 'поверь', 'у', 'нас', 'то']

# %%
corpus

# %%
freq_dict = Counter(corpus)
freq_dict_sorted= sorted(freq_dict.items(), key=lambda x: -x[1])
list(freq_dict_sorted)[:10]
# Out:
# [('не', 69472),
#  ('и', 55166),
#  ('в', 52902),
#  ('я', 52818),
#  ('RT', 38070),
#  ('на', 35759),
#  ('http', 32998),
#  ('что', 31541),
#  ('с', 27217),
#  ('а', 26860)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
first_100_freqs = [freq for word, freq in freq_dict_sorted[:100]]
plt.plot(first_100_freqs)
plt.show()

# %% [markdown]
# Закон Хипса -- обратная сторона закона Ципфа. Он описывает, что чем больше корпус, тем меньше новых слов добавляется с добавлением новых текстов. В какой-то момент корпус насыщается.

# %% [markdown]
# ## Задание 1.
#
# **Задание**: обучите три классификатора:
#
# 1) на токенах с высокой частотой
#
# 2) на токенах со средней частотой
#
# 3) на токенах с низкой частотой
#
# Сравните полученные результаты, оцените какие токены наиболее важные для классификации.

# %%
len(freq_dict_sorted)
# Out:
# 351101

# %%
dict(freq_dict_sorted)
# Out:
# {'не': 69472,
#  'и': 55166,
#  'в': 52902,
#  'я': 52818,
#  'RT': 38070,
#  'на': 35759,
#  'http': 32998,
#  'что': 31541,
#  'с': 27217,
#  'а': 26860,
#  '...': 22363,
#  'меня': 20656,
#  'у': 18928,
#  'как': 18280,
#  'так': 16839,
#  'D': 16575,
#  'это': 16542,
#  'мне': 16337,
#  'все': 14763,
#  'ты': 13412,
#  'но': 12949,
#  "''": 12471,
#  'Я': 12315,
#  '``': 11467,
#  'то': 11433,
#  '..': 11392,
#  'по': 11294,
#  'уже': 10180,
#  'за': 10038,
#  'же': 9628,
#  'ну': 8742,
#  'А': 8635,
#  'только': 8065,
#  'бы': 8041,
#  'еще': 7829,
#  'да': 7413,
#  'вот': 7244,
#  'тебя': 7161,
#  'нет': 7078,
#  'когда': 6676,
#  'очень': 6436,
#  'сегодня': 6377,
#  'будет': 6368,
#  'к': 6357,
#  'день': 6332,
#  'хочу': 6137,
#  'он': 6064,
#  'просто': 6052,
#  'от': 5654,
#  'было': 5484,
#  'тебе': 5436,
#  'мы': 5414,
#  'из': 5406,
#  'И': 5308,
#  'тоже': 5142,
#  '—': 5063,
#  'до': 4749,
#  'надо': 4731,
#  'там': 4723,
#  'даже': 4683,
#  'его': 4655,
#  'теперь': 4494,
#  'есть': 4464,
#  'вообще': 4442,
#  'если': 4319,
#  'для': 4192,
#  'о': 4159,
#  'нас': 4056,
#  'В': 4051,
#  'завтра': 4049,
#  'могу': 3971,
#  'она': 3960,
#  'всё': 3855,
#  'Не': 3847,
#  'Ну': 3818,
#  'буду': 3792,
#  'сейчас': 3747,
#  'У': 3520,
#  'Как': 3519,
#  '....': 3511,
#  'знаю': 3417,
#  'без': 3358,
#  'тут': 3270,
#  'раз': 3261,
#  'кто': 3144,
#  'они': 3116,
#  'или': 3099,
#  'люблю': 3080,
#  'больше': 3008,
#  'ничего': 2998,
#  'со': 2971,
#  '2': 2923,
#  'про': 2846,
#  'вы': 2795,
#  'всегда': 2793,
#  'блин': 2780,
#  'Но': 2752,
#  'почему': 2741,
#  'можно': 2720,
#  '3': 2698,
#  'чем': 2677,
#  'С': 2676,
#  'мой': 2667,
#  'хорошо': 2641,
#  'был': 2641,
#  'Вот': 2629,
#  'спасибо': 2617,
#  'спать': 2598,
#  'дома': 2594,
#  'потом': 2562,
#  'ещё': 2480,
#  'время': 2478,
#  'их': 2469,
#  'такой': 2451,
#  'может': 2411,
#  'Это': 2386,
#  'делать': 2370,
#  'год': 2353,
#  'чтобы': 2320,
#  'Сегодня': 2269,
#  'себя': 2243,
#  'этот': 2241,
#  'была': 2234,
#  'ни': 2219,
#  'быть': 2213,
#  'всем': 2103,
#  'после': 2089,
#  'Мне': 2080,
#  'всех': 2050,
#  'опять': 2047,
#  'где': 2025,
#  'много': 2011,
#  'себе': 1999,
#  'вас': 1951,
#  'хочется': 1926,
#  'этого': 1916,
#  'моя': 1898,
#  'пока': 1896,
#  'такое': 1889,
#  'лучше': 1886,
#  'На': 1876,
#  'Все': 1875,
#  'такая': 1861,
#  'хоть': 1857,
#  'ее': 1813,
#  'такие': 1795,
#  'один': 1778,
#  'всего': 1768,
#  'Да': 1757,
#  'плохо': 1749,
#  'дня': 1741,
#  'нужно': 1693,
#  '9': 1674,
#  'настроение': 1664,
#  'этом': 1663,
#  'новый': 1662,
#  'Так': 1658,
#  'под': 1654,
#  'совсем': 1654,
#  'что-то': 1626,
#  'ли': 1626,
#  'него': 1607,
#  'домой': 1605,
#  'во': 1596,
#  'нам': 1578,
#  'того': 1540,
#  'потому': 1533,
#  'мои': 1531,
#  'вам': 1527,
#  'через': 1524,
#  'конечно': 1521,
#  'Спасибо': 1517,
#  'скоро': 1494,
#  'жизни': 1479,
#  'утро': 1473,
#  '5': 1465,
#  'утра': 1457,
#  'ведь': 1455,
#  '4': 1434,
#  'равно': 1421,
#  'Что': 1419,
#  'люди': 1415,
#  'ахах': 1399,
#  'тогда': 1396,
#  'вчера': 1390,
#  'никогда': 1387,
#  'никто': 1379,
#  'Ты': 1370,
#  'года': 1368,
#  'чего': 1366,
#  'школу': 1348,
#  'НЕ': 1327,
#  'весь': 1316,
#  '1': 1315,
#  'мной': 1312,
#  'Если': 1297,
#  'жизнь': 1295,
#  'нравится': 1291,
#  'ж': 1267,
#  'болит': 1263,
#  'DD': 1256,
#  'мама': 1251,
#  'хотя': 1239,
#  'Хочу': 1234,
#  'одна': 1228,
#  'человек': 1225,
#  'эти': 1217,
#  'думаю': 1214,
#  'вроде': 1201,
#  'них': 1195,
#  'моей': 1195,
#  'из-за': 1187,
#  'Блин': 1185,
#  'какой': 1182,
#  'понимаю': 1180,
#  'тобой': 1179,
#  'лет': 1177,
#  'правда': 1174,
#  'смотреть': 1172,
#  ':3': 1171,
#  'часа': 1169,
#  'Завтра': 1168,
#  'Только': 1167,
#  'уж': 1164,
#  'кажется': 1157,
#  'жаль': 1155,
#  'о_О': 1153,
#  'снова': 1148,
#  'людей': 1145,
#  'точно': 1141,
#  'идти': 1139,
#  'кого': 1133,
#  'круто': 1116,
#  'сразу': 1114,
#  'ему': 1112,
#  '10': 1107,
#  'gt': 1105,
#  'ахаха': 1102,
#  'Теперь': 1092,
#  'почти': 1092,
#  'скучаю': 1089,
#  'два': 1085,
#  'который': 1083,
#  'ночь': 1072,
#  'сделать': 1069,
#  'сижу': 1063,
#  'были': 1056,
#  'ночи': 1045,
#  'давно': 1045,
#  'х': 1028,
#  'хотела': 1021,
#  'фильм': 1019,
#  'сильно': 1017,
#  'бля': 1016,
#  'этой': 1003,
#  '“': 988,
#  'пойду': 985,
#  'всю': 981,
#  'вечер': 980,
#  'думала': 978,
#  'улице': 967,
#  'нельзя': 965,
#  'мало': 960,
#  'Мы': 959,
#  'которые': 954,
#  'О': 951,
#  'её': 948,
#  'надеюсь': 942,
#  'lt': 940,
#  'прям': 937,
#  'эту': 936,
#  'будут': 935,
#  '”': 929,
#  'как-то': 929,
#  'Почему': 929,
#  'столько': 925,
#  'писать': 925,
#  'Когда': 920,
#  'минут': 917,
#  'наверное': 916,
#  'сама': 914,
#  'том': 914,
#  'ладно': 914,
#  'сказала': 913,
#  'времени': 911,
#  'сколько': 909,
#  'раньше': 909,
#  'свой': 896,
#  'ней': 886,
#  'Новый': 883,
#  'ей': 882,
#  'каждый': 882,
#  'школе': 880,
#  'нормально': 880,
#  'че': 880,
#  'значит': 879,
#  'хочет': 873,
#  'Очень': 870,
#  'перед': 866,
#  'первый': 862,
#  'тем': 861,
#  'свою': 857,
#  'будем': 853,
#  'тот': 847,
#  'долго': 847,
#  'самое': 843,
#  'настроения': 842,
#  'кстати': 841,
#  'ибо': 838,
#  'чтоб': 834,
#  'снег': 830,
#  'зачем': 829,
#  'эта': 825,
#  'немного': 822,
#  'самый': 819,
#  'посмотреть': 816,
#  'скучно': 815,
#  'друг': 815,
#  'вк': 811,
#  'та': 808,
#  '.....': 807,
#  'году': 806,
#  'Кто': 805,
#  'сам': 804,
#  'чуть': 804,
#  'ним': 803,
#  'работу': 801,
#  'приятно': 801,
#  'об': 800,
#  'жалко': 794,
#  'такого': 793,
#  'ахахах': 793,
#  'сказать': 792,
#  'пиздец': 789,
#  'фото': 789,
#  'щас': 783,
#  'телефон': 782,
#  '8': 782,
#  'куда': 778,
#  'НГ': 771,
#  'рождения': 769,
#  'вместе': 766,
#  'при': 766,
#  'сказал': 764,
#  '-D': 761,
#  'кем': 761,
#  'привет': 760,
#  'ужасно': 758,
#  'норм': 755,
#  'Он': 755,
#  'человека': 747,
#  'часов': 746,
#  '--': 746,
#  'нг': 744,
#  'Всем': 743,
#  'оно': 742,
#  '6': 740,
#  'именно': 740,
#  'неделю': 739,
#  'смотрю': 738,
#  'помню': 738,
#  'таки': 736,
#  'нее': 734,
#  'им': 733,
#  'слишком': 728,
#  'поняла': 723,
#  'кто-то': 722,
#  'блять': 721,
#  'Надо': 721,
#  'три': 721,
#  'чувство': 719,
#  'интересно': 717,
#  'говорит': 711,
#  'давай': 710,
#  'кому': 710,
#  'какая': 707,
#  'жить': 702,
#  'обидно': 700,
#  'жду': 699,
#  'бывает': 697,
#  'одной': 696,
#  'знает': 694,
#  'второй': 690,
#  'Вы': 687,
#  'быстро': 685,
#  'работает': 684,
#  'уроки': 683,
#  'назад': 682,
#  'своей': 682,
#  'никак': 682,
#  'стоит': 681,
#  'ко': 680,
#  '«': 679,
#  'чувствую': 679,
#  'дела': 676,
#  'пор': 675,
#  'видео': 674,
#  'знаешь': 672,
#  'недели': 667,
#  'рядом': 665,
#  'нету': 665,
#  'пришла': 663,
#  'свои': 660,
#  '7': 660,
#  '»': 660,
#  'боюсь': 654,
#  'найти': 652,
#  'этим': 651,
#  'осталось': 651,
#  'пару': 650,
#  'утром': 647,
#  'твиттер': 647,
#  'ага': 644,
#  'хватает': 643,
#  '^_^': 642,
#  'час': 639,
#  'б': 636,
#  'стало': 632,
#  'лишь': 632,
#  'дней': 628,
#  'Еще': 628,
#  'сидеть': 628,
#  'главное': 627,
#  'Уже': 627,
#  'последний': 626,
#  'момент': 626,
#  'DDD': 624,
#  'голова': 624,
#  'забыла': 622,
#  'друзья': 622,
#  'моего': 620,
#  'здесь': 620,
#  'весело': 618,
#  'ехать': 618,
#  'туда': 618,
#  'Люблю': 615,
#  'холодно': 611,
#  'Нет': 610,
#  'Доброе': 609,
#  'читать': 609,
#  'сих': 608,
#  'работе': 607,
#  'Меня': 604,
#  'написать': 603,
#  'поэтому': 602,
#  'грустно': 601,
#  'говорят': 598,
#  'пожалуйста': 596,
#  'иногда': 594,
#  'зато': 594,
#  'реально': 593,
#  'отлично': 589,
#  '…': 588,
#  'пошла': 588,
#  'Просто': 584,
#  'з': 583,
#  'твит': 583,
#  'гулять': 582,
#  'Даже': 581,
#  'будешь': 580,
#  'ждать': 577,
#  'amp': 577,
#  'пол': 568,
#  'По': 568,
#  'дальше': 568,
#  'видела': 567,
#  'хотел': 567,
#  'За': 564,
#  'вижу': 564,
#  'работать': 562,
#  'твой': 562,
#  'днем': 560,
#  'страшно': 559,
#  'таких': 559,
#  'получается': 558,
#  'хочешь': 558,
#  'любимый': 557,
#  'какие': 556,
#  'сделала': 555,
#  'мое': 554,
#  'снега': 553,
#  'ненавижу': 548,
#  'рано': 548,
#  'какой-то': 547,
#  'вся': 545,
#  'лень': 545,
#  'мою': 543,
#  'обычно': 543,
#  'глаза': 542,
#  'пусть': 541,
#  'особенно': 540,
#  'самом': 539,
#  'целый': 539,
#  'те': 539,
#  'рада': 538,
#  'деньги': 538,
#  'более': 537,
#  'зима': 536,
#  'капец': 535,
#  'походу': 535,
#  'ходить': 535,
#  'нечего': 535,
#  'одного': 531,
#  'Сейчас': 530,
#  'эх': 530,
#  'будто': 529,
#  'тви': 528,
#  'своих': 528,
#  'еду': 527,
#  'фотки': 526,
#  'другой': 525,
#  'ТЫ': 524,
#  'больно': 523,
#  'скорее': 522,
#  'выходные': 522,
#  'ой': 521,
#  '20': 517,
#  'сука': 517,
#  'понравилось': 515,
#  'каникулы': 512,
#  'над': 511,
#  'аж': 509,
#  'нужен': 509,
#  'купить': 508,
#  'вопрос': 508,
#  'идет': 508,
#  'хороший': 507,
#  'подарок': 507,
#  'прости': 506,
#  'нашла': 505,
#  'любовь': 504,
#  'Всё': 503,
#  'две': 502,
#  'ЧТО': 502,
#  'устала': 502,
#  'дело': 501,
#  'место': 499,
#  '0': 499,
#  'придется': 499,
#  'работы': 498,
#  'євромайдан': 495,
#  'моих': 494,
#  'Мой': 492,
#  'написала': 488,
#  'такую': 487,
#  'понял': 485,
#  'учить': 484,
#  'нибудь': 482,
#  'Хотя': 481,
#  'одно': 480,
#  'Моя': 479,
#  'кроме': 478,
#  'месяц': 477,
#  'понедельник': 475,
#  'думал': 474,
#  'купила': 474,
#  'Она': 472,
#  'вечера': 471,
#  'друзей': 470,
#  'денег': 470,
#  'МЕНЯ': 470,
#  'типа': 469,
#  'Вчера': 468,
#  'сон': 468,
#  'иду': 467,
#  'честно': 467,
#  '-/': 467,
#  'ночью': 466,
#  'Привет': 466,
#  'желание': 466,
#  'вставать': 466,
#  '99': 466,
#  'правильно': 463,
#  'нового': 462,
#  'хуже': 461,
#  'кофе': 460,
#  'кино': 460,
#  'песни': 457,
#  'руки': 456,
#  'вечером': 455,
#  'погода': 455,
#  'деле': 454,
#  'парень': 454,
#  'России': 453,
#  'День': 452,
#  '30': 451,
#  'Бля': 451,
#  'говорить': 451,
#  'декабря': 450,
#  'Жаль': 449,
#  'чо': 449,
#  'Мама': 447,
#  'слова': 444,
#  'пора': 443,
#  'класс': 443,
#  'любит': 442,
#  'мир': 441,
#  'смогу': 440,
#  '15': 438,
#  '^^': 438,
#  'начала': 438,
#  'собой': 437,
#  'могла': 437,
#  'пишу': 435,
#  'Опять': 435,
#  '12': 434,
#  'чай': 433,
#  'постоянно': 432,
#  'несколько': 431,
#  'экзамен': 430,
#  'самая': 430,
#  'видимо': 429,
#  'Сижу': 429,
#  'боль': 428,
#  'своего': 427,
#  'вместо': 427,
#  'пойти': 424,
#  'меньше': 423,
#  'Эх': 422,
#  'делаю': 422,
#  'наверно': 420,
#  'друга': 419,
#  'пишет': 419,
#  '11': 418,
#  'таким': 418,
#  'https': 416,
#  'раза': 416,
#  'часто': 415,
#  'нужна': 415,
#  'Надеюсь': 415,
#  'чувак': 413,
#  'папа': 413,
#  'наш': 412,
#  'ааа': 411,
#  'должна': 411,
#  'можешь': 408,
#  'твои': 408,
#  'вдруг': 407,
#  'НА': 405,
#  'сказали': 405,
#  'голову': 405,
#  'короче': 404,
#  'сердце': 403,
#  'др': 402,
#  'соскучилась': 401,
#  'К': 401,
#  'либо': 401,
#  'бесит': 400,
#  'смешно': 400,
#  'удачи': 400,
#  'стал': 399,
#  'решила': 399,
#  'доброе': 398,
#  'школы': 397,
#  'самого': 397,
#  'знала': 396,
#  'проснулась': 396,
#  'хд': 395,
#  'этих': 395,
#  'тех': 394,
#  'голос': 392,
#  'одну': 392,
#  'После': 392,
#  'своим': 392,
#  'музыку': 391,
#  'счастья': 390,
#  'Скоро': 390,
#  'видел': 390,
#  'получилось': 389,
#  'Год': 388,
#  'голове': 388,
#  'играть': 387,
#  'КАК': 387,
#  'ноги': 386,
#  'обратно': 386,
#  'сделал': 385,
#  'Может': 385,
#  'могут': 384,
#  'хорошего': 384,
#  'сезон': 382,
#  'сначала': 380,
#  'То': 380,
#  'До': 377,
#  'Пока': 377,
#  'получится': 376,
#  'сожалению': 376,
#  'Какой': 375,
#  'субботу': 374,
#  '–': 374,
#  'ЭТО': 374,
#  'слово': 373,
#  'хорошая': 373,
#  'похоже': 373,
#  'концерт': 372,
#  'наконец': 371,
#  'наши': 371,
#  'ахахаха': 370,
#  'ними': 370,
#  '100': 369,
#  'ужас': 369,
#  'действительно': 368,
#  'обязательно': 367,
#  'обожаю': 366,
#  'месте': 364,
#  'скучать': 364,
#  'понятно': 363,
#  'ок': 363,
#  'МНЕ': 363,
#  'любви': 362,
#  'даа': 362,
#  'забыл': 361,
#  'этому': 361,
#  'нашей': 360,
#  'заболела': 360,
#  'самые': 358,
#  'последнее': 357,
#  'сложно': 357,
#  'серия': 356,
#  'оказывается': 356,
#  'мысли': 355,
#  'моим': 354,
#  'сходить': 354,
#  'истории': 354,
#  'против': 353,
#  'везде': 352,
#  'твиттере': 351,
#  'подарки': 351,
#  'город': 351,
#  'ох': 350,
#  'неё': 350,
#  'пары': 349,
#  'знать': 348,
#  'умею': 348,
#  'лох': 348,
#  'Они': 346,
#  'смотрела': 345,
#  'далеко': 345,
#  'должен': 344,
#  'сериал': 344,
#  'снов': 344,
#  'которая': 344,
#  'происходит': 343,
#  'шк': 343,
#  'любимая': 343,
#  'ваще': 343,
#  'общем': 343,
#  'супер': 341,
#  'настолько': 341,
#  'видно': 341,
#  'боже': 341,
#  'интернет': 340,
#  '13': 340,
#  'странно': 339,
#  'печально': 339,
#  'болеть': 338,
#  'делаешь': 338,
#  'НУ': 338,
#  'ума': 337,
#  'мило': 337,
#  'дни': 337,
#  'радует': 336,
#  'понять': 336,
#  'пить': 336,
#  'девушка': 336,
#  'написал': 336,
#  'зря': 335,
#  'прямо': 335,
#  'лето': 334,
#  'лента': 334,
#  'песня': 334,
#  'стала': 334,
#  'наконец-то': 333,
#  'песню': 333,
#  'вспомнила': 333,
#  'поздно': 333,
#  'молодец': 332,
#  'увидела': 330,
#  'Хорошо': 329,
#  'безумно': 329,
#  'читаю': 329,
#  'A': 328,
#  'проблемы': 328,
#  'хватит': 328,
#  'никуда': 328,
#  'людям': 326,
#  'говно': 326,
#  'ради': 324,
#  'никого': 323,
#  'TukvaSociopat': 323,
#  'работа': 322,
#  'стыдно': 322,
#  'Или': 321,
#  'ТАК': 321,
#  'слушаю': 321,
#  'Кстати': 320,
#  'каток': 320,
#  'говорю': 319,
#  'брат': 318,
#  'конец': 318,
#  'шоке': 317,
#  'метро': 317,
#  'Что-то': 317,
#  'печаль': 317,
#  'иди': 316,
#  'дом': 316,
#  'увидеть': 316,
#  'успела': 316,
#  'любишь': 314,
#  'лол': 314,
#  'Ох': 314,
#  'посмотрела': 314,
#  'видеть': 314,
#  'ощущение': 313,
#  'классно': 313,
#  'взять': 313,
#  'ДА': 313,
#  'лучший': 312,
#  'забыть': 312,
#  'крутой': 311,
#  'одни': 311,
#  '......': 310,
#  'кот': 310,
#  'месяца': 310,
#  'городе': 309,
#  'пятницу': 309,
#  'л': 309,
#  'никому': 308,
#  'волосы': 308,
#  'девушки': 307,
#  'вокруг': 307,
#  'тому': 307,
#  'Есть': 306,
#  'выходных': 305,
#  'недавно': 305,
#  'родители': 305,
#  'хотелось': 305,
#  'плакать': 305,
#  'вещи': 305,
#  'часть': 302,
#  'оч': 302,
#  'большое': 301,
#  'верю': 301,
#  'неделя': 300,
#  'января': 300,
#  'узнала': 300,
#  'красиво': 300,
#  'слушать': 300,
#  'счастье': 300,
#  'называется': 300,
#  'лицо': 299,
#  'школа': 298,
#  'вами': 298,
#  'дети': 298,
#  'Q': 297,
#  'между': 297,
#  'Москве': 297,
#  'умер': 297,
#  'урок': 296,
#  'праздник': 296,
#  'ВСЕ': 294,
#  'новости': 294,
#  'девочка': 294,
#  'понимаешь': 294,
#  'Там': 293,
#  'нахуй': 293,
#  'подруга': 292,
#  'Где': 292,
#  'зачет': 291,
#  'горло': 291,
#  'мамой': 291,
#  'делает': 291,
#  'черт': 291,
#  'тяжело': 290,
#  'Зачем': 290,
#  'пишут': 290,
#  'температура': 289,
#  'нами': 288,
#  'новогоднего': 288,
#  'например': 288,
#  'НО': 287,
#  'Ненавижу': 287,
#  'купил': 286,
#  'твоя': 286,
#  'пошел': 286,
#  'ребят': 286,
#  'возможно': 285,
#  'все-таки': 284,
#  'начинается': 284,
#  'говорила': 284,
#  'сюда': 284,
#  'где-то': 283,
#  'Рождения': 283,
#  'нь': 283,
#  'новые': 283,
#  'двух': 283,
#  'хотят': 283,
#  'Вам': 282,
#  'большой': 282,
#  'Буду': 282,
#  'мог': 282,
#  'хорошее': 282,
#  'Боже': 282,
#  'готова': 282,
#  'учиться': 281,
#  'игры': 281,
#  'конца': 281,
#  'любить': 281,
#  'конце': 281,
#  'дааа': 279,
#  'кого-то': 279,
#  'спокойной': 278,
#  'Ахаха': 277,
#  'хаха': 277,
#  'сделали': 276,
#  'самой': 276,
#  'пять': 275,
#  'сами': 275,
#  'улицу': 275,
#  'итоге': 275,
#  'танцы': 274,
#  'вечно': 274,
#  'решил': 273,
#  'серии': 272,
#  'ребята': 272,
#  'прошло': 272,
#  'музыка': 272,
#  'слов': 272,
#  'сплю': 271,
#  'нужны': 271,
#  'думать': 271,
#  'З': 270,
#  'начал': 270,
#  'маме': 270,
#  'какое': 269,
#  'пришлось': 269,
#  'последние': 269,
#  'подряд': 268,
#  'своими': 268,
#  'милый': 268,
#  'номер': 267,
#  'проблема': 267,
#  'уснуть': 267,
#  'классе': 266,
#  'нем': 266,
#  'выспалась': 265,
#  'какая-то': 265,
#  'гости': 264,
#  'пошли': 264,
#  'любимые': 264,
#  'кушать': 264,
#  'дура': 264,
#  'идиот': 263,
#  'скажу': 263,
#  'Хоть': 262,
#  'письмо': 262,
#  'любимого': 262,
#  'болею': 262,
#  'фигня': 261,
#  'последняя': 261,
#  'почему-то': 261,
#  'история': 260,
#  'говорил': 260,
#  'сессия': 260,
#  'От': 259,
#  'Россия': 259,
#  'тему': 259,
#  'дали': 259,
#  'сидит': 258,
#  'Интересно': 258,
#  'знал': 258,
#  'планы': 258,
#  'тож': 258,
#  'шо': 257,
#  'o_O': 257,
#  'пришел': 256,
#  'хорошие': 256,
#  'классный': 256,
#  'всей': 256,
#  'твиты': 255,
#  'зиму': 254,
#  'ппц': 254,
#  'ем': 254,
#  'дождь': 253,
#  'красивая': 253,
#  'которых': 253,
#  'одном': 253,
#  'свое': 252,
#  'моему': 251,
#  'сдавать': 251,
#  'магазин': 251,
#  'увы': 251,
#  'летом': 251,
#  'ооо': 250,
#  'мире': 250,
#  'прошел': 250,
#  'моем': 250,
#  'что-нибудь': 249,
#  'первой': 249,
#  'Вообще': 249,
#  'ответ': 249,
#  ...}

# %%
x_train, x_test, y_train, y_test = train_test_split(df.text, df.label)

# %%
k_train = []
for i in x_train:
    k_train.append([token for token in word_tokenize(i) if token not in punctuation])

# %%
len(freq_dict_sorted)//3
# Out:
# 117033

# %%
#1.1) На токенах с высокой частотой
cnt = 0
hight_freq = dict()
medium_freq = dict()
low_freq = dict()
for word, freq in freq_dict_sorted:
    if cnt <= 117033:
        hight_freq[word] = freq
        
    elif cnt >= 117033 and cnt < 117033*2:
        medium_freq[word] = freq
        
    elif cnt >= 117033*2:
        low_freq[word] = freq
        
    cnt += 1

# %%
k_hight_train = []
k_medium_train = []
k_low_train = []
for i in k_train:
    k_hight_train.append([token for token in i if token in hight_freq ])
    k_medium_train.append([token for token in i if token in medium_freq])
    k_low_train.append([token for token in i if token in low_freq])

# %%
str_hight_train = []
str_medium_train = []
str_low_train = []
for i in k_hight_train:
    str_hight_train.append(' '.join(i))
    
for i in k_medium_train:
    str_medium_train .append(' '.join(i))
                           
for i in k_low_train:
    str_low_train.append(' '.join(i))

# %%
str_hight_train
# Out:
# ['Самое Доброе проведенное с любимым человеком цените и каждым мигом проведенным друг с другом',
#  'Didiwka ааа хочу посмотреть тожееее .... аааа хочу домой',
#  'ты просто посмотри на эту мадам и потом вспомни Юлю',
#  'Никогда не ешьте салаты вызывающие у вас сомнения',
#  'RT Постоянно хочу тыкнуть вилкой в попу моего мужика Он по дому в трусах ходит а попа у него такая хорошая Прям',
#  "`` Китаец не выдержал шопинга со своей девушкой и покончил жизнь самоубийством спрыгнув с седьмого этажа торгового центра '' Слабак",
#  'в очередной раз коллективный разум оказался полезным Жуик есть что добавить',
#  'Настроение дно Еще и соня в столовку дежурить ушла буду одна сидеть все уроки Скучать',
#  "sa_cerese да как будто мы против `` скромно ответил за всех '' Х Х Х Это ж тентакли тентакли всегда в тему ...",
#  'нет времени нету .. но обязательно дочитаю я не буду по магазинам искать она в самом начале декабря вышла только',
#  'RT Пусть они перестанут кидать эти фото и видео Я же умру щас',
#  'TovarischSuhova эээх .... вот это да .....',
#  '.... Как же запарился в шараге Так даже на тренировке не устаю',
#  'ну я всё равно лох ибо на гитаре учусь не по аккордам а по нотам мне так не везёт',
#  "`` Я уже как-то что ли наверно немного соскучился '' ахахаха",
#  'В кого ты превращаешься в полнолуние — В единарога с растущей ромашкой на пупке http //t.co/Ii2kgcYmcV',
#  'даже я не беспокоюсь о себе как он сегодня беспокоился о моем состояние и самочувствие',
#  'RT Сижу вконтакте жду чуда пока мне кто нибудь напишет но увы',
#  '1 ноября Какой был прекрасный день Как сейчас помню мое настроение с утра и после лент и куда оно исчезло теперь',
#  'Сказала бывшему однокласснику что хочу стать http',
#  '« Группа ГАЗ » начала выпуск автомобилей « Урал » с двигателем « Евро-4 » завод amp quot Урал amp quot группа ГАЗ',
#  'efimenkooo оки я просто переживаю за заю ой короче вся надежда на он только ее слушает',
#  'RT всё сердечко ёкнуло ... шоу начинается блеать',
#  'Haartrockner воистину открыла немецкий пунш',
#  'Папе на роботу надо в 10 так он сейчас встал что бы завести меня в школу переживает что бы я по холоду не ходила',
#  "`` '' '' ждите '' '' Жрец я тебя жду '' '' спасибо '' '' Хорошо хоть прист есть '' Аааа милости",
#  'Хочу погулять со своими любимыми переночевать у них все вместе но этого не когда не будет',
#  'так я ж не про тебя я в общем и целом',
#  'lyana4 доброе утро правильно красоту надо творить с самого утра',
#  'RT очень боялась тебя потерять но это случилось http 0 Я',
#  'myxale котики для меня больная тема',
#  'поставил Lotus Symphony 3 — ковыряю на первый взгляд норм когда прогрузится ну и это лотус нотес касается',
#  'Какого то фига Катя не звонит и не пишет наверное опять не погуляем сегодня ...',
#  'поняла что не начну готовиться к экзаменам пока вообще не D',
#  'VikaLangor так вот как все работает .. некая возможность выхода в свет',
#  'так и не погуляли на свадьбе',
#  'ммм какое чудесное зимнее утро а я ложусь спать всем спокойной ночи',
#  'место написанно мегафон что за нах http',
#  'RT netbeans срочно понадобился сабж версии на сайте нет где брать',
#  'Исправить бы еще по физике но уже позно',
#  'Посмотрела инстаграм некоторых знакомых личностей посмеялась от души куда ж нам до таких то звезд -D',
#  'Как пережить этот первый рабочий день ... Капец какой-то ... Спала час ниче не ела ... Надо больше воды ...',
#  'RealRitaSkeeter Рита Вас будет не хватать сегодня вечером Решение не идти на бал окончательное',
#  'А вот и 6-й подарок если честно то порадовал меньше всего http',
#  'о привет или по сто раз за ночь просыпаешься',
#  'Преподша рассказывает что хохляцкие вузы отчисляют студентов которых заметят на майдане',
#  'i_zemler я знаю но для вашего это только эпизод ф',
#  'Спасибо за этот день я счастлива мне безумно приятно за поздравления и подарки спасибо вам родные',
#  'Сегодня в очередной раз убедился что знаю женщин и как они мыслят А я ведь говорил',
#  'Так легко быть сильным искренне веря в чудеса http',
#  'RT MadMaryCherry lazy__turtle Мне совсем не нравится то сколько мы общаемся Ну да ладно Хороших снов Айеро http',
#  'RT AnastasiBurya на место своих одноклассников',
#  'RT мой D',
#  'у меня тоже есть свитер со снеговиком меня тоже',
#  'ShipKlaine_ to_over_kill БОЮСЬ',
#  'я уж и забыла как круто на фонтанке в районе верфей какой-то совершенно не Петербург ...',
#  'Хорошее здоровье это когда в аптеку ходишь только за презервативами ...',
#  'Че все грустят Не грустите всё у вас будет хорошо:3',
#  'RT Вечером участники делали милые подарочки и нас песнями класс ШСВ ОТДЫХ',
#  'Всю ночь снился дурацкий экзамен Причем я неплохо так отвечала Но лучше уж лесбиянки Голова трещит',
#  'drunktwi Так нельзя есть дождик',
#  'RT Ну почему у некоторых много мозгов а у него дефицит прям',
#  'как же я хочу отдельный кабинет — любую темную коморку можно даже без окон',
#  'А если Стасик будет весь ..... К нему потянутся женщины страны ...',
#  'RT pillSa5 ТРИ ПРОДАЖНЫХ ДЕБИЛА http //t.co/bynCKuQ2No',
#  'Надо уже собраться и позвонить Ненавижу говорить по телефону',
#  'я так хотела к бабушке облом место не было в машине',
#  'Ну кароче я конкретно заболела 9',
#  'RT Irishka_iraira выздоравливай',
#  'а вдруг повезет и в моей ленте много людей из моего города D Линта кто в живет правильно никто',
#  'но всегда получается что и Байга ахах',
#  'да не за что только у меня нету',
#  'RT IMitory ух ты ты заметил да поэтому',
#  'Голова как -то необычно болит Быстрее бы конец',
#  'blondgal_lina кто поведал тебе этот великолепный способ D',
#  'Комп не работает сижу с телефона мне',
#  'посвящаю своему брату adxam_uz С его победой и успехом в качестве',
#  'frnkmustdie_ сук я на эту постоянно залипаю чуханчик ты http',
#  'WinnyPuhh_ как мне теперь жить 77 Не интересно же будет 9 9',
#  'khiger Смена кадров это следствие своего роста Правда часто наблюдаем следствие деградации Бизнес Политика',
#  'Больше часов играю в и все еще не научился по памяти рисовать',
#  'RT kota_Oo_oO Alisa_Belieber_ Снаступающимтвиттерский с',
#  'подари мне волшебные выходные',
#  'RT Omega777oleg Всем кто обожает арбузы http',
#  'а еще я помню как я туда и учила экономику D',
#  'msdarren16 Когда у нас появляются мандаринки их съедаю я Больше они никому не достаются х',
#  'Есть где праздновать НГ — не ни места ни денег ни друзей Дома вконтактике буду сидеть http',
#  "RT microbash Алекс да у меня 2 дня не было нормального компа/ alisa_dorian звучит как `` у меня 2 года не было нормального секса ''",
#  'RT albina01D RipLouisGrandma Сегодня умерла бабушка Луи Очень жаль У меня муражки слезы буд-то моя бабушка умерла http',
#  'cezaruschaman black_swan33 Удивительное тёплое место просто в городской суете И такие открытые и добрые',
#  'RT artemblayn 20 фолловеров еще и 1000 Поможете RT',
#  'RT Apollo_Loki Loki_Killjoy Крылышко у тебя все получится Ты займешь 1-е место D Да прибудет с тобой Локи D http',
#  'RT Seeker_miracle Муж щас скинет свои сиськи я весь в ожидании DD',
#  'RT brysokO_o наконец то тренировки Андрюха много вещей правильных сказал я был бы рад если он нас еще д…',
#  'видела сегодня anay_huaynay позвала ее а она была в наушниках',
#  'Tastyfruitcake ну бл я за сегодня ничего кроме этого не ела',
#  'Katya_Supernova ща все себе запилят особенно D',
#  'm_levinskaya Ну что ж ты одна то с мешками',
#  'Фотосессия просто супер классные фотографии но мама .....',
#  'Альтернатива акции coca cola с крышечками собери 10 люков и получи п зды от жкх=',
#  'RT buywaikeacar RT ceemanride RT bouvtprogecel Камызяки ушли на тайм-даун квн Через год вернутся ребят =-',
#  'во время поцелуя',
#  'Gonchareenko приходи ко мне у моих на любой вкус есть лак',
#  'ТОЛЬКО Я МОГУ ОБ',
#  'я хочу целовать его ... а он так далеко .. и он НЕ мой ...',
#  'RT _Do_or_Die__ двадцать четыре mtvstars One Direction',
#  'А знаете почему у вас нету подарка на новый год Потому что вы не послали смс с кодом на номер деда мороза TEAMFOLLOWBACK',
#  "RT 83Mira '' IgorBorissov `` Виталик меня вот тот бил '' http //t.co/4NVJZSDzCy ''",
#  'Началось предновогоднее -/ .....',
#  "в просторах и понимаю плохо все Х Предыдущие места работы я находила на === ''",
#  'Офигенный день день позитива бегал как идиот целый день танцы офигенны хоть я и ракал но мне очень понравилось',
#  'сначала не нравился этот парень justsaymeow но после ивент поменял свое мнение Мяу ты шикарен',
#  'увижусь сегодня со своими родными я так соскучилась',
#  'слово Господа http',
#  'Задолбалась я тебя любить Когда же бля разлюблю D',
#  'только не сейчас мне надо поесть иначе вырвет',
#  'я не успела совсем домой приехала только в 11.30 мне после примерки опять в надо было',
#  'Блин а где можно заказать http Уже где только не смотрел нигде нету',
#  'господи боже как же я уже отвыкла вставать рано ... ааааааааааа',
#  "RT ElDLV `` '' тупое слово его так долго писать",
#  '... кстати почему ты мне не пишешь',
#  "Наткнулся на `` Умка ищет друга '' ... ностальгирую Все таки советские мультики можно смотреть в любом возрасте",
#  'RT hewoxofubogu лять че она в записи на диск тормозит безбожно',
#  'весь день с Ленкой пробыли в городе посвятили день подаркам и все-таки я все купила очень устала но приехала довольная',
#  'именно а вообще из за моих',
#  'Снег снеег Снег Аууу ты где снег Тебя нет',
#  '5 месяцев ждала когда они снова http',
#  'smileinrain это очень грустно но я завидую жизнь у него удалась однозначно',
#  'awesome_bear grnngn вооот кто-то знает толк в далеких морских путешествиях',
#  'Тяны нас путают хуйня пиздец',
#  'KOT_C_MAPCA_ ТОЛЬКО У НАС НЕТ',
#  'RT Всегда мечтала отменить Новый год в атмосфера своя другая ^_^',
#  'RT Vika_Van любим я скучаю очень',
#  'Я хочу ко всему придираться это плохо С трудом удерживаю рот закрытым а руки — подальше от клавиатуры',
#  'Капец нога болит очень сильно после вчерашних горок',
#  'это так про меня http',
#  'скоро отключат инет за неуплату мой совет всем не ругайтесь с родителями',
#  'насморк и красное горло Пошла пить горячее молоко с медом',
#  'RT RT tiftajupo RT coetranbyjes RT maitiawreathter Самый тяжёлый день- это четверг',
#  'Kafka_Frank Сойдет но хочу лучше Сесссия скоро нужно готовиться учить ... веселые выходные намечаются',
#  'ну и выкопала я себе ямку ... все прежние труды насмарку так еще и потом до зимы следующей не',
#  'KorobkoDarya не знаю я перестал видеть в нем смысл',
#  'saki_sagan вот печально это Может с опытом придет разве что',
#  'На этой неделе намечается два новых Внезапно х',
#  'Ну как обычно подошли познакомиться к нам мы нахуй послали -D',
#  'Опять температура блииин http',
#  '54_zah akutata11 Alex_ya13 chernyj1974 krykbryk UkrainianLife ioshig Нет гороскопу и',
#  'какой то испанец пишет мне на английском про татухи а я как баран отвечаю',
#  'блядь я думал сегодня чутка потеплее будет',
#  'Я проехал только половину дороги а у меня уже садится телефон',
#  'Sr_Void про это всерьез о_О даже про гитару говорила точно-точно',
#  'Теперь остается только ждать пока ...',
#  'завтра сессия по обществу а я ничего не читала и даже учебник не открывала',
#  '2.5 часа это слишком не оправдал моих надежд этот спектакль кушать еще хочу хнык',
#  'Сколько килограмм тебе нужно для счастья — http',
#  'RT достал отдыхать приезжай уже зависть',
#  'сон у меня в 5 дней жил это друг ромы который долбаёб оказалось что они с очень спокойные парни',
#  'лицензии для продуктов Kaspersky Думал что к тому моменту как я напишу — ключей уже не будет Но нет Теперь на но',
#  'RT SitNoff Открытка к научной библиотеки http',
#  'RT спасибо и тебе хорошего дня з Ого 4 дня Почему Уехала куда-то',
#  'это была самая скучная поездка в маршрутке',
#  'Отвратительный черный котяра моей меня х',
#  'ага вот с косплей та же хрень',
#  'VovaBaglaev ахахах прям люблю ее в такие а так она меня бесит',
#  'я спросила откуда у них мои данные Сказали от МТС Я в хуе',
#  'Еще 2 ч можно поиграть или же пересмотреть какой-нибудь фильм Эх был бы старый хард хорошие были там фильмы',
#  'блин хотел выйти на улицу .. а щас вижу дождь идет',
#  'Нет все-таки когда болит голова невозможно радоваться жизни От этого она начинает еще сильнее болеть',
#  'О и я год назад был на канарах ... почему мы не встретились',
#  'LeeMalfoy вам еще нужна бета У уж очень люблю это дело',
#  'Админ подслушано негодует Подписался еще 1 человек Где же 15',
#  'Попахивает новым годом в одиночестве Ни разу в жизни не было Молодой надо всё пробовать',
#  'RT Бумер 2 — нормальное продолжение истории жаль только что концовка без хеппиенда ...',
#  'Хочется волейбола посмотреть а придется довольствоваться телеком',
#  'минута 45 Молодец Света в твит ее фамилию не буду',
#  'ахахах у меня такой же на полочке стоит Я как узнал что на нельзя покрасить расстроился',
#  'RT litelp голос такое чувство будто Евровидение смотрю',
#  'о чем ты говоришь я никогда не делать такие гифки как ты х',
#  "RT blye_syomga Аркашка должен сменить юн на `` охуенный пидрила '' D",
#  'Последнее время даже на твиттер времени не нахожу Не читаю и не пишу',
#  'всё плохо с Завтра КОНТРОЛЬНАЯ по геометрии D 2 консультации -_- Щито делаешь',
#  'И завтра до обеда наверное не смогу оплатить',
#  '6 часов вечера За стенкой перфоратор Уныние ...',
#  'Любите поезда А я вот люблю .. Дорога дорога и музыка Быть очень круто особенно если у тебя хороший вкус',
#  'RT Настроения нет я очень устала хочу спать но мне нужно прочитать книгу срочно Сил мне да побольше',
#  'Jelenatorrrr У ТЕБЯ АНИ БЫ ЕСТЬ 9',
#  'третий пункт как вознаграждение за первые два однако ты',
#  'Сижу в макдаке ... куда бы пойти в понедельник вечером НЕ домой',
#  'будзе добра гэта у скайпе 31',
#  'контрольная по .. и я вместо того что бы учить пишу этот ебаный твитт 99 9',
#  'Я очень боялась тебя потерять но это случилось',
#  "`` В чём дело крошка Ты у нас плакса Нет .. сэр ... Она `` мэм '' `` х Всё я умер окончательно хд",
#  'nugumanova96 потому что в тот раз только на пробном занятии была до этого я не посещала курсы',
#  'Я повеселила историка D У НЕГО ТАКИЕ КОГДА D',
#  'RT почему у меня всегда все так когда очень чего-то жду и хочу всегда такой облом',
#  'что у тебя случилось',
#  'RomaTweetcorn он вам ответил',
#  'RT меня мечта утром прийти на кухню а мой пафосный распиздяй варит мне кофе http',
#  'Пришла домой на часах Была в школе',
#  'блиииииин ... морально убита сама себя от так от',
#  'ya_my_love нового вроде ничего а прода это продолжение фанфика',
#  'Иногда ты показываешь что ты дерзкая — Прости http',
#  'MAXIMOV69 Не слышал о таком сейчас читаю его историю Спасибо интересно',
#  'hullibulli lemurka91 у меня бабушка как-то кота с балкона ебанула месяц лечили не знаю может они доводят до такой степени',
#  'помогите в пропала собака ребенок все глаза .. может кто видел http',
#  'MyDishaLove новогодний корпоратив свой сделать в какой-нибудь кафешке всей группой',
#  'Жду любимого поскорей бы он пришло http',
#  'DukocTb_FJ я говорю у меня спортивный пакет каналов и там один из Но я не подписана',
#  'Аааа не хочу никого обидеть ну почему я должна что-то',
#  'а все из-за того что я не сказал ей о ещё парне истеричка',
#  'как же мне нравится жить в собственном доме',
#  'любимый с днём рождения тебя ты заставил меня полюбить кфас и не будь счастлив http',
#  'Спасибо большое скучай там без нас',
#  'The_SonOfGod врага надо знать в лицо а данного пациента особенно',
#  'Обожаю стюардесс блин так круто они выглядят как с Ааааа Божественно',
#  'Да конечно блин вообще 4 урока должно gt http',
#  'Наконец-то пришла зима ... и холода Скоро на лыжах',
#  'crazy_mehokrab ааа вы же на зимнее точноо я забыл',
#  'моя любимая среда жаль она так быстро заканчивается всегда',
#  'Почему мама с бабушкой хотят купить мне платья обувь на каблуках Не хочу я Тем более на нг никуда не иду Лучше бы щеночка подарили',
#  'RT zocebexynoh со словами -Где наш малыш Вот он И так раза 3 Брат не http',
#  '_catcore_ все вы так говорите а потом не',
#  'Вот ведь выбор Новый телефон или поездка в Куала-Лумпур',
#  'ее бес ... SitNoff Имя её неизвестно RT пикет с плакатом « не виноват » провела женщина около здания СК',
#  'печально EXADirectioners',
#  'RT VMeysters ну',
#  'Диван люди не от хорошей жизни придумали',
#  'характеристика для добрая честная самая Добра тебе',
#  'Поставил на тестовую машину Ниасилил',
#  'блин ты же не осталась на чаепитие сегодня',
#  'в столовой села на разлитый по лавочке чай ... Удача всегда со мной D',
#  'RT xamaxipytag Я — творческая личность высокие душевные метания ...',
#  'RT WTF_not_found super_hazza_69 что DD опять там D',
#  '_hayley_way_ PolinaAltynnik naastyax Up_the_air_ спасибо они мне пригодятся найти телефон',
#  'Dj_Tim_2014 сочувствую тебе мне жаль твоего друга но терять тут некого потому что ничего нет',
#  'rubeautyinsider как тонкие только разных цветов и очень теплые вместо меховой шапки кстати советую меховые уши',
#  'книжный и http',
#  'RT kyfocibemogu Утро Питера идёт дождик .... Хорошо наверное под шум дождя спать ...',
#  'На Земле так много прекрасного ... Но знаете моя любовь-это самое прекрасное ...',
#  'не знаю что будет после того когда я уеду .... с ума наверное сойдем',
#  'RT',
#  'Небо поможет нам небо поможет всем нам .... И нам не сессию и оставят все как есть ... Ребят не надо переносить ну пожалуйста',
#  'аххах читала твиты старого аккаунта сразу вспомнила то происходило в том году',
#  'Перешли на новогоднее оформление ... всех с наступающим http //t.co/Jj2yiM8WIJ http',
#  "_stasvlasov а Диана я не помню как фамилия .. на `` З '' начинается ... с пела",
#  'только что приехала домой замёрзла очень',
#  'Откопал очередной проект с Йорном Ланде на вокале — Mundanus Imperium Нормальное такое название',
#  'все меня бросила как папка Синдзи',
#  'и на теб благодаря',
#  'http Мастер-класс по укладке ламината',
#  'RuFollowMe слишком уже мейнстримом стал',
#  'Возможно я не самый лучший человек в мире но .. Ладно шучу ..',
#  'я заржала даже тут сохраню XD просто шутки про рулят алюминь D http',
#  'завтра именины у моего мишки которого мне подарил начальник D',
#  'о да именно я ненавижу такие голосования за то что они так долго тянут зато потом так приятно осознавать что мы выиграли',
#  'Капец так всё долго хочу уже в дорогу http',
#  'Еду в Барнаул а на против меня сидит дед в наушниках и ногами под музыку смешно наблюдать',
#  'А мамы все нет ...... пол часа уже жду .... а она в автобусе едет',
#  'В общем что хочу звание художника не претендую ХД http',
#  'RT Эстафета олимпийского огня прекрасно настоящий праздник',
#  'BilanOfficial настроения Вам http',
#  'Второе место в Очень удивлены с ребятами А ночь после дискотеки была весёлой',
#  'так для этих слов все это и делалось',
#  'lebiaga привет да уж давно ... Да все не до твитера было ...',
#  'natachka_1996 сейчас да а вообще нет я скучаю по ней очень',
#  'PaulinaBur что же стало толчком к таким глобальным переменам D',
#  'на подарок маме придется занять у бабули ибо своих денег нехера',
#  'twidade_lucks если зайти через 4 года на эту же почту то так же будет D у меня на другой почте чуть поменьше http',
#  'nastyatyutyunik нууууууууууу Настя не',
#  'завтра вечер будеет круто весь класс придет',
#  'не помеха к тому же мы с тобой месяца 3 не виделись',
#  'PoluschenkoVika я написала Иди на трассу',
#  'RT DLGreez Мне летом 20 стукнет Я щас об этом подумал и охуел 20 лет Двадцать Сукпздц скоро умирать 99',
#  'не ссы я к тебе не полезу DD Может быть хдд',
#  'DianaPayne_ ну помнишь на физику он чет завтра на профиле он раздаст их и мы будем решать',
#  'vishenevskaya Sasha_UusanI1DI эх блин',
#  'lbelyanina ты о какой Усилители натрий и прочее BambinaMalvina',
#  "`` идем те на школьную дискотеку кто то последний год учится последний раз в школе тусануть с теми людьми кто уйдет '' ахахахаха нет",
#  'Какая ложка меня мне так хуево',
#  'RT Не люблю доводить людей до слез своими рассказами потом чувствую себя виноватым',
#  'А самое чудесное за сегодня полежала на жене D Хоть кто-то из нас мягкий И вообще что вообще происходит Что правда понимают',
#  'MOPE_HET просто пишу обычно только на англ в тви привычка только сегодня что-то много на русском пишу',
#  'Ну вот а я хотел выебнуться а вы актрису эту не знаете',
#  'stepaniansiuza1 Да вот концертик по английскому был',
#  'Ахахахахаха RT nzlobin Действительно несколько неожиданное развитие событий http //t.co/vcpBfnY3tu',
#  '-Я хочу ребенка .. -Нет Мужчина должен в первую очередь думать ... -Да И о чем ты думал пока трахал меня',
#  'вот ты быстрая а я все еще первый не могу досмотреть времени нет',
#  'Urangoo_A Жиргээ ээ удахгүй Чи бүх шүү',
#  'RT Stacey_Maslow когда нибудь лет так через',
#  'Это самого сильного и умного Еще если добавят по смогут еще узнать кто в добавок еще и красивый',
#  'В голове её опилки не-бе-да А вот в лифчике бумага ... это да .... http',
#  'RT так круто на горочке покатались с Сашкой вспомнили детство',
#  'понедельник в школе прошёл довольно таки нормально',
#  'Наконец-то на репетициях мы уже не ходим и сидим а реально зачёт ура',
#  'Юля неужели ты думаешь что я до такой степени наивная',
#  'Ritona_ тебе по воздуху моя',
#  'RT Kepochka я бы хотела пообщаться Биллом и так обнять его',
#  'Надеюсь проснусь увижу разъёб Копенгагена и новый рекорд КриРо',
#  'тоже так буду делать можно А еще я вспомнила свой недавний твит о и их gt D',
#  'Сколько Это я столько вешаю Все я худею .........',
#  'я так скучаю по — я тооже http',
#  'таки придется винду установить wine и новые игры несовместимы ..',
#  'еще раз с днем рождения будь всегда такой позитивной как сегодня',
#  "RT 83Mira '' davletkildeeva Я слышу как мои будущие дети говорят мне только попробуй родить нас в этой стране вот только",
#  'У всех праздник все гуляют с друзьями А мои предки как обычно меня не куда не пускают ... Спасибо огромное ...',
#  'RT Итак наш вечер посвященный прекрасной Лии Мишель подошел к концу надеюсь что вам понравилось http',
#  'да решишь ты хд в б1 внимательно у меня были ошибки в б1 и а с часть не засчитали потому всего 52 балла',
#  'VivienneLola913 а я вчера хотела купить но не было',
#  'Daria_Styles22 один раз было больше не видела пока что',
#  'Вот такие сообщения я получаю в 2 часа ночи D http',
#  'McFaul Спасибо конечно но поздравлять к сожалению не с чем Те кто находится у власти в нашей стране Конституцию',
#  'ахах я не прочь иметь схожие черты с такой красотой',
#  'AllaElesina Запах и алкоголя она не переносит но однажды с удовольствием по полу упавшую сигарету играла с ней ..',
#  'Сделал погоду оформление и покушал ну разве не умница я',
#  'Полина взяла телефон и удалила фотку из инсты вот вам принцессу http',
#  "научилась делать переворот вперед и '' ура",
#  'RT Слава Богу этот мужик не бросился под электричку и не решился я б не знаю что мы делали ужасно страшно',
#  'Уровень уровень российского чемпионата высок и растёт На дне',
#  'Какой был лучший фильм этого года — Не знаю не помню http',
#  'Ура Да выруби ты оповещения в своем хреновом',
#  'я знаю людей которым первая часть понравилась',
#  'И Кристиана который только пришел и еще мало знаком но уже занимает свое место в твоем Уже свой почти',
#  'Обедаю с Лучшим волонтером ЯО 2013 года Настенька ты умница Безумно рад и горд за тебя http //t.co/6tZoy3JKB1',
#  'RT zajalicepob Поспорил с другом Он утверждает что у гитар 3 струны — нейлон а 3 — железо Завтра буду праздновать победу',
#  'ДА НЕУЖЕЛИ НЕЛЬЗЯ УЖЕ ЧТО ЗАКРЫТ ВХОД НА АДЕКВАТНОЕ САМА ЖЕ СВОЕ СЧАСТЬЕ',
#  'мне крутых песен слушать нечего',
#  'пхахахха D засовываешь внутрь и ..',
#  'RT chemical_docwho ic_kr да стул в школе снимал с парты и задел Я даже не понял где он там был',
#  'RT Bloody_SAW82 tasteYOGURT ПРИВИТ МИЛАЯ Я УЖЕ ВЕРНУЛСЯ СО КАК ТАМ ТВОЙ ДЕНЬ',
#  'MAHDAPIHA логично просто начни с ней общаться вот и все',
#  'а у меня Мэнсона в плеере включился не с проста х',
#  'Кто-то уже готовится ко сну а кто-то учить химию http',
#  'Говорят если тебе снится человек значит он о тебе думает ... блин как всегда не тот кто надо',
#  'Хаха Кристина меня жирафом называет потому что до меня очень долго все доходит',
#  'ты мне так и не ответила',
#  'Как в этом мире тяжело жить mtvstars Justin Bieber',
#  'ещё и сочинение по литературе писали зашибись день',
#  'именно Я включила что б посмотреть Боба а тут включаю и херня какая то ну збс Я расстроена',
#  '... до Варшавы и http',
#  'Какой приятный вечер Свечи елка БИЛЕТЫ http',
#  'По сути 1й день в А я уже хочу обратно',
#  'Zyoshka1 это просто ужасно ... вот что значит Россия печально',
#  "`` ну ты и ... '' я делаю все что могу",
#  'еврейский музей в Москве неожиданно узнала что египетские пирамиды евреи',
#  'ахаха уже читателей та мне все равно D но число же янепошлый http',
#  'стала еще на 1 год взрослее не верится мне',
#  "HarunaToia Я хочу почитать `` '' но времени нет",
#  'RT Суки свет выключили Пол часа ждать где-то бля',
#  'звучит как предложение не для меня',
#  'ня центрим пробелы ставит в конце кирилицы где то в гугле я это уже видел',
#  'Точный адрес Деда Мороза http',
#  'Dakara Boku wa H ga Dekinai — 04 А глаза всё равно автоматически переключаются на чулки Лисары',
#  "kio_sftp неосилил перелить 7-гиговый файл завис на 5.7гб Пристрелил — kde сказало что `` всё докопировалось ''",
#  'Expelliarmus77 ну вот же он я',
#  'RT saynskay Сегодня еще один день',
#  'мне нельзя ленивые вареники',
#  '61 кг о_О Это ... Хз как описать Живот не плоский но жир больше не висит Но есть один большой трабл за пять дней пос',
#  'gazepledge bilberry_mm если я накрашусь то выгляжу примерно так D http',
#  'Всё-таки любить приятно а если ещё покажет',
#  'Мне вот интересно Почему у женщины мозг устроен вроде также как у мужчины а вааще по другому',
#  'ZakDios передай им что керлинг ваще огонь помню в просыпался в 5 утра чтоб керлинг смотреть правда они почти все проиграли',
#  'ахха а у вас хто блін мої 4 в ...',
#  'Господи хоть бы все прошло завтра нормально я должна сдать эту дурацкую географию',
#  'Стою дежурю по школе мимими http',
#  'vgy7ed я сама редко почему ты будешь редко заходить',
#  'блять да что это за хуйня ... че делааать ааа',
#  'но была девчонка в свободном режиме за 15',
#  'почему меня все не любят плак-плак',
#  'RT tutby Домрачева на последней стрельбе упустила победу в индивидуальной гонке http Обидно',
#  'Всегда завидовала талантливым людям и людям с прямыми руками',
#  'рода обстоятельства пытались сбить меня с пути но я все-таки написанный курсач Чят го каток сегодня там мило',
#  'netstrelka не хочется такое ощущение что',
#  'а я хочу быть маленькой и слабой',
#  'я такое удобное место выбрала на этой олимпиаде ихихи головой не пришлось вертеть все перед глазами было',
#  'неужели я такая ворчливая бабка пипец ........',
#  'смотрю Папины дочки на ivi.ru Приятный сериал Очень добрый И забавный Так мало в мире позитива',
#  'Девушки скоро тоже начнут этим мериться',
#  'RT nylumykimix мужчина называет вас КАПУШЕЙ назовите его СКОРОСТРЕЛОМ http //t.co/h1EjHwEY1J',
#  'RT momo_oo3 И чувство это вызвал мужчина лет сорока в этот момент он как раз покупал у чуть в стороне продавца жареный арахис',
#  'Ахахахахахахахах надо и мне так сделать',
#  'не ты просто съезжаешь с темы вот покажи мне официальный бланк ты попросту не хочешь выполнять условия соглашения',
#  'По обмену можно поехать только снова в универ Увы я не энергетик и не',
#  'ото DD',
#  'Что-то захотелось чай tea http',
#  'stevebest Да читала я научный труд на эту тему ... только не сохранила себе а найти его потом так и не смогла',
#  'Я заслужила значок Hero в программе 250 11 http',
#  'то что вконтакте сидят все .. ведут единицы',
#  'сегодня я себе нравлюсь поэтому бегу на встречу с другом',
#  'выйдите из 3. не ну серьезно свои части тела с спать с',
#  'naastuuusha блин это ужасно Город ахиренный а теперь кроме проблем с дорогами проблемы с Жаль людей которые оказались там',
#  'сказали что до Рождества снега не будет',
#  'по-моему лошадь испугалась Тао D по глазам вижу D http //t.co/j8suv8bwkJ',
#  'Сегодня на майдане будет валить КАК ЖЕ Я ХОЧУ Жаль вот только нечем в такое время будет домой добраться',
#  'uniLis__Porn мне нравится немецкий с только вот в моей школе он начнется с 9',
#  'Эх голова раскалывается или это похмелье или температура снова',
#  'LesyaParshikova olololouis в тьме D',
#  'RT karrimov Ппц что у нас рядом с домом творится Новый Год блин http //t.co/uqS3jlctpO',
#  'И так сегодня мне надо было ехать в фото-школу но поскольку я заболела и на улице гололёд я не поеду Да ну на хер надо D',
#  'RT vitabakan abakanskiy не стань случайно http',
#  'RT gesmapesdans читаювзаимно нууу любимые фолловьте меня Я ведь всех фолловлю без исключения',
#  'неет мне не надо У меня есть Оставь себе одного хотя бы',
#  'julegg если приобрести домой то довольно скоро А еще в ней есть ^_^ :3',
#  'Так не охото завтра идти на учебу но строгая Ксюша все равно заставила D',
#  'на улице так скользко благодаря Юле упала спасибо что ли',
#  'Ох а я только учу',
#  'Осталось день простоять да ночь продержаться',
#  'ай яй зачем с мамой ругаешься',
#  'Весёлая о событиях на Украине СМИ Евромайдан Шоу продолжается Танцуют все http',
#  'RT PoliticanaRu navalny Российские дипломаты в США http //t.co/IHLmwNbxJn',
#  'Воды нет нет работы нет Зато неделя перед новым годом будет загруженная',
#  'RT fisinupewp Солнце светит-я болдею дождь я фанарею я от жизни ловлю кайф все прекрасно my ife http',
#  'Fuckest_Dasha акцент ведущей начинает бесить после трех программ D',
#  'те у кого есть дети самые счастливые люди в мире http',
#  'А вы уже сразу его бараном обзывать',
#  'RT AkimauI нувсё 9',
#  'Моя любимая обиделась http',
#  'лучше сидеть на попе и ныть как все несправедливо Не мой работу работать Любимую бе бе бе',
#  'Контакт не хочет ни кому отправлять мои открытки',
#  'Настроение говно надо бы выпить а не охота',
#  'Заказала кружку с с Молодежки Через 2 недельки будет уже у меня',
#  'а потом утром не встать',
#  'RT Overcast_Kid_ BOBA_KOT lukky_monster И это называется я вижу ее каждый день и попрощались мы около 2 часов назад D',
#  'У Юли очень классный парень даже фотка есть правда вспышка не сработала',
#  'ахаххахахах а как ты можешь если не секрет',
#  'С чего для тебя начался этот год — с боли в животе http',
#  'ооо я в последнее время в 7 то с трудом встаю',
#  'сегодня в 8 вечера позвонила мама спросонья подумала что уже 9 утра и я опоздала на автобус такиедела',
#  'У меня опять остановились часы с утра ... ровно в 8',
#  'Прихожу в форму после дня варенья всем доброго вечера http',
#  'я сделаю из медведя а внутри там будут лепестки роз ок ахаха — ок http',
#  "приходишь с ... смотришь на ся в зеркало и говоришь ... '' блооо ... и это я так гуляла '' ... D FF_RU",
#  "Иду на остановку а на встречу мне хач катится Я такая думаю `` чтоб ты уебался хач ибаный '' и понимаю что я сказала это вслух рядом с ним",
#  "СМИ `` Медведев поручил к маю подготовить законы '' Ради в Следовательно будет профанация Увы",
#  'А еще я была ... на Ну и не удержалась понра http',
#  'голова вроде прошла но мне все равно так плохо',
#  'его чинят там неполадки',
#  'Поспала блин а тут такие новости ... ну я так надеялась ну емае',
#  'Мой брат суши На сковородке С',
#  'Elliseeva да прекрасная выставка будет тоже ее жду',
#  'Вечер с lovely nastya_roschina был классный сон невероятный и тут надо в стрессе доделывать практикум ^^ вот в такие моменты ..',
#  'lovelessoon TomAnnailla annet0940',
#  'все на месте не переживай Как что изменится ты обязательно об этом первая узнаешь ...',
#  'Кто чуть не проспал на электричку Аня чуть не проспала на электричку',
#  'Sallivan_me danya2307 Ну Ой не знаааю Надеюсь что после часов 4-5 свободна буду а ты там что',
#  'Даже валяться не в чем',
#  'То чувство когда мама кошку любит больше чем меня',
#  'Когда я только зарегистрировалась в твиттере то не думала что у меня будет больше чем 10 читателей D Ну хоть в чем то я ошиблась D',
#  'RT Noizer_99 sasha_vasyukova не правда пиздеть не мешки Пусть сначала а потом',
#  'Встала в 7 вечера Надо поесть и пиздовать спать дальше',
#  'RT хочу спать а не учиться',
#  'мадрид с рынком даже близко не сравнить de San http',
#  'ооо отличная идея завтра же это и сделаю',
#  'RT Alexey_Andronov Нормально все Павел “ Нижний встретил Alexey_Andronov не слишком дружелюбно http ”',
#  'XAPPu_CTyJIEC расскажи мне что за кино стоит смотреть мне название понравилось D',
#  'Kimmi_Dara там с какой стороны ни подойди везде пары D',
#  'Спокойной ночи спасибо за настроение http',
#  'Да классный и она очень счастлива ей так хорошо нескем не было — да да да и еще раз да http',
#  'Мне нужны большие мощности чтобы нормально сделать лабу',
#  'И вновь мы с тобой в телефонном режиме',
#  'Балин пробный ЕГЭ по а я не готовилась',
#  'punk_rock53 это было очень неожиданно когда она начала падать',
#  'тебе придется второй раз удалять',
#  'ЦСКА лохи Бавария втф остальное пойдет Юве с вообще не доиграли походу наш циклон на Турцию пошел',
#  'RT xytorosisap капец Ни минуты спокойной ... почему я всем сегодня нужна',
#  'Люди ради которых ты готов был отдать всего себя на тебя Забей живи в кайф',
#  'The___Master подари братюне прошлый меня напрягает',
#  'Первые сезона по зимнему',
#  'SovSekretno CIO_Optimal Это уже просто смешно право ...',
#  'Хотя че я ... Сам же в написал что наушники 13 декабря D',
#  'Да и найдём себе в немца в ну а в',
#  'У них там ещё и собака ... вот псинку жалко',
#  'кто там меня спрашивал как я тут живу Вот как то так http',
#  'Когда он ноет по утрам что не хочет в садик мне хочется сесть рядом и зарыдать Но меня то некому пожалеть',
#  'RT поздравляли с международным женским днем выпила 50 грамм шампанского теперь я пьяная и работаю с трудом',
#  'RT http одна сигарета отнимает 15 минут жизни а один урок 45 минут.=',
#  'RT красивая http',
#  'Как спать так работа появляется ппц но зато завтра будет',
#  'RT giaritedoc1974 ххх я хочу ребенка ууу ты пол часа назад хотела мороженое о_О',
#  'А могли бы быть в экономику России ... А кто выводит Те же самые Жулики и страну гады ...',
#  'До добралась Правда выбор маленький и все почему-то',
#  'Кататься на в -17 можно но сцуко очень холодно и .... пожалуй бороду и усы придется сбрить',
#  'собираюсь на улицу .... чувствую приду домой вся мокрая и',
#  'ааа жую жвачку и плачу Блиин мама почему ты не сказала что она с эвкалиптом и такая мятная ааа помогите блин аж слезы идут',
#  'я понимаю меня больше интересует что он делал у тебя в планшете',
#  'Проснулся от боли в сердце пустое сердце еще никогда так не болел',
#  'KionHakashime угу криворукая малость D и ко мне на ты можно',
#  'Офигенный день день позитива бегал как идиот целый день танцы офигенны хоть я и ракал но мне очень понравилось',
#  'RT yadaha6000 Последняя серия молодежки сегодня печальбеда',
#  'choppamyu ничего нет что у тебя мысли из головы',
#  'Бляяяяяяя Любимый умер ...... http',
#  '-Давай под елкой сфоткаемся -Ну давай http',
#  'Не оставляют они нас Правда дома не призрак требует с меня и других 1600 за им',
#  'Насморк кашель глаза слезятся ... Заболеваю я походу',
#  'Впервые совсем не волнуюсь сдам или нет Просто хочу уже быть свободной как все нормальные люди',
#  'RT fyladafijina да все понимают-путин вор.да.но навальный вор-показала история с спиртозаводиками и лес .. навальный поддерживает гомиков',
#  'Все любят его ... А он любит только меня ... Так приятно',
#  '62Mashka оО Надо бы посмотреть И как О',
#  'Потому что у него плеер ааа ...',
#  'Вступил в группу Расскажи о ней друзьям Волгограда',
#  'почти никто не поздравил с праздником с суки НИПРАЩУ 111',
#  'до нового года несколько часов а новогоднего настроения как не было так и нет P.S с наступающим дорогие мои',
#  'але я не написати тобі лс — Та ну перестань ти хоть є в мене в друзях http',
#  'http 1300 просмотров моего убогого фристайла',
#  'RT Kyo_oppa Работаю в компании извращенцев http',
#  'ахахаххаха я не могу с тебя ахахаха',
#  'да Вадим он не едит',
#  'Kandinskiy_D PakV в ящике 6 бутылок всего Пак повёлся на 650 р',
#  'Я хочу 600 флвр потерялись было почти 700',
#  'не вериться что такое наступит http',
#  'RT lentaruofficial Это все как-то нереально грустно служба безопасности отняла у инвалида костыли Путин просит не обижаться http //t.co…',
#  'Хочу приготовить на ужин свинину в кисло-сладком соусе но боюсь',
#  'Хватит звонить мне ... -Почему -Моё сердце не выдержит такого количества успокоительного ...',
#  'nastya_adm0109 знал бы я сам Но знаешь .. Один хороший человек сказал что то в роде',
#  '3 дня ребята Дома не сидим на тусу летим D http',
#  'блин Саша ты офигенный испытание на кладбище на высоте прошел ну правильно твоя стихия же',
#  'С ним все очень плохо А у тебя',
#  'Покупка квартиры и авто в один день Финансы упали близко к нулю',
#  'И как обычно к ночи у меня поднимается настроение музыка',
#  'Блин блин блин Я уже не могу ждать Как ты там Что у тебя Всё ли хорошо',
#  'MindlessR0mance нееет зачем ты так он мне не хочет говорить кто он но я то скоро узнаю но он точно не говно и не какашка',
#  'Ну вот блин завтра опять четверг опять фильмы делать',
#  'до сих пор убираюсь в комнате уже устала',
#  'whitebro_ дак она же до 5-ти вечера будет проснёшься поди',
#  'Ну нет у меня друзей с которыми можно устроить PARTY',
#  'Только первый день катка а меня уже бесит ... Она чуть не украла мои деньги хорошо что все за меня заступились',
#  'Нужно снять ролик на Мисс никаких идей ...',
#  'Артемида Re Re Беседка Всем привет http',
#  "Эх только у меня никогда не бывает проблемы `` что бы такого посмотреть '' Ответ всегда простой — ничего",
#  'прошло несколько часов А мое День Рождение ни чем не отличается от обычного дня',
#  'Я так сильно тебя люблю что боюсь о себе напомнить и нарушить твою идилию',
#  'tonnita_stark Изи что с настроением ремонт мать его',
#  'гипс ложат что вы с ним сделали',
#  'с какого хрена у меня не отправляются сообщения',
#  'Сука я на правую стать не могу .... сука как же больно ...',
#  'А этот гей кавказский каким-то образом прошел охренеть ..',
#  '_6412193615461 tatusjkr А у нас плюсовая температура и всё уже растаяло От вчерашний сказочной красоты ничего не осталось Ни следа',
#  'котик накормлен и спать гладить не требуется',
#  'RT Катя все больше меня удивляет D',
#  "Собираюсь в `` секту '' D В 7 Часов встала а на пары встать блин не могу ...",
#  "Забавно `` сюда https ''",
#  'MedvedevRussia Вы уже протестировали yotaphone стоит ли он 20000 рублей Если не стоит то просто не отвечайте',
#  'Два часа с Алиной искали подходящие платья в школу так ничего и не нашли',
#  'Ann_Glam_ ммм или вы о своем о женском',
#  'ухаха The Calling — Wherever You Will Go уж не затюнился ли я по ошибке на Лав-радио',
#  'пойдемте гулять а только потом заберите меня ночевать а то в общагу не пустят',
#  'yourdoctorcox вау как приятно с спасибо коксик и мы тебя',
#  'Subkhangulovaa забери нас собой эх я так хочу домой',
#  'Deep__Serenity я долго жал ретвит и не понимал в чем дело',
#  "`` Утаагүй зуух '' гэж МСиЭс баахан мөнгө хийсэн одоо `` утаагүй болгох эсгий '' гэж Таванбогд баахан мөнгө хийх нь дээ",
#  'Тадададам ... Горло болит настолько что больно просто а не когда и голова еще Мама заразила она сама такая сейчас',
#  'Манту сделали Ужааас Теперь не покушать мне',
#  'Фигура классная Фуу неет',
#  'кажется музыку из нашей машины слышно аж на мжк ахах слышишь',
#  'YG опубликовали фотки и Теперь ясно кого они --',
#  'Орфография хромает на обе ноги ... толи пальцы кривые то ли медленные ... не успевают за мозгом печатать ... D',
#  'SpawnRu да тормозит ужасно По моему мнению с прошлого года',
#  'juliyvchirkov я конечно загуглила но',
#  'На улице так красиво Но дома под пледом 100 лучше',
#  'Большое большое вам',
#  'Ppodorozhnik это у них сегодня 21 а в 28',
#  'mashababe2010 ахах спасибо конечно но это не про тебя ...',
#  'шикарный вечер я хоть посмеялась от души Вика Дима Илья В',
#  'Сегодня меня вызвали на по у нас сегодня с ним будем',
#  'ааааааа хуле нет этого канала',
#  'Универ даёт академ С работой тоже всё решено Вот первый пункт — первый плюс во всём этом',
#  'Вот нашла я и мои братишки на море http',
#  "Меня начали удалять из `` друзей '' Пока",
#  'Приятного тебе С Даа пытаешься ты ешь а значит не помнишь об уроках D',
#  'в 3 часа коррекция выбор очередного для тату',
#  'Питер Джексон сошел с ума мне не понравилось Тауриель и Кили что за сантименты что это было вообще Хоббит',
#  'Моя шея Сегодня всё намного хуже не могу повернуть головой шею разрывает дикая боль ..',
#  'самой не вериться ну вот такая грустная история',
#  'RT как обычно поржали с ним над всеми D',
#  'Интрига вокруг Даши слишком быстро Осталось выяснить зачем ее пиарят',
#  'RT pollifelton DASHKA09D а то если учесть что у нас была репетиция к НГ и ещё у меня в субботу у ней ЭКЗАМЕН чует моя жопа что это пл…',
#  '2014 год уже стал для меня ужасным нах такие вписки',
#  'Хочу пойти на каток но жутко болит голова',
#  'наш город всегда стоит Погода лишь немного усугубляет этот процесс',
#  'miss_kuzi о а ты же тоже было дело там всякий',
#  'CrucifiedShadow о да я понимаю Но эту я не могу тебе отдать По крайней мере не старшую',
#  'Извечная проблема что В голове уже закончились все рецепты',
#  'GaGa_oo_lala RonyLiss MsWildFan Vlada188 Day13Beautiful Popsicle_K2isOn Uunicorrnn ВС D',
#  'RT ебаная геометрия не чё не получается',
#  'AnnoaBoreisha я так тоже примерно короче вчера учила в произведение нашла место где я ноты не те играю бля сукапздц',
#  'RT AvengedSatan 99Kristi4ka НЕУЖЕЛИ ТЫ ТУТА И Я ТЕБЯ ДОСТАЛ НАКОНЕЦ ПРИВИТ D',
#  "RT zemant Влюблен в слово `` бывает '' ибо оно везде уместно — ты ебанат — бывает — У меня кот умер — Бывает",
#  '— это грустно но именно поэтому я их не ношу',
#  'Знаешь я чёт подумал подумал а на фига Всё итак ясно ... — ну лан http',
#  'Делаю эту научную работу Так все надоело Еще одну нужно подготовить ..',
#  'Дорогой Дедушка Мороз мой самый желанный подарок можешь оставить в паркинге или гараже http',
#  'Люблю свою Надеюсь папа тоже ее полюбит аха',
#  'стараюсь не задумываться над этим х и названия половины первый раз вижу х',
#  'Блин температура ваще не сбивается походу завтра опять дома',
#  'з/п не дали ну и как вот я теперь на НовыйГод пойду',
#  'Смотрю видео про классные и понимаю что я бы все сейчас отдала чтобы покататься на них',
#  'Почему на моей кроватке не ловит 3G такая несправедливость',
#  'в лучшем случае смотреть',
#  'abrauprt на 3 D она всё равно не нужна была для поступления правда я потом об узнала с',
#  'Як же я за тобою скучала Нам мороз не Ми своє літо http',
#  'grjazni_garri жалко будет жечь их города и сёла А на штык кишки детей я и вовсе заплачу',
#  'Вчера на работе у напарницы играла одна песня я говорю знаю ее она это из В итоге я ее нашла у себя это был Rocky',
#  'UAREMEANDIAMU ну воот я не успела написать тебе',
#  'bielov63 ты в тебе',
#  'RT lizalitovka pain_my_life омг омг D буду ждать тебя в субботу',
#  'МТС пожелал хорошего дня просто так пришла смска странно но приятно',
#  'DubcovaOfficial Я за И пусть все будут счастливы',
#  'да так живот что разогнуться не было сил',
#  'RT Завтра понедельник неееееееет жизньболь',
#  'Я еще вас не достал тем что постоянно завожу новый акк в тви D',
#  'БЛИИИН ЗА ИЗ ДУШУ ПРОДАМ http',
#  'Вокруг одни начальники… даже послать некого',
#  'У тебя есть любимые книги музыка море приятных воспоминаний люди которым ты дорога и ещё вся жизнь Так что всё',
#  'Блиииин Я сегодня не посмотрю Manchester United в 21:30 Удачи МЮ',
#  'а я и не раньше пора бы уже начинать панику',
#  'Прошел тест на темперамент 2-й раз показал что я как так блять В том году же был холерик D',
#  'Сегодня какой-то нехороший день у меня Телефон наушники не опознает у блога как-то умудрился шаблон сломать да еще',
#  'S_Kornitsky это еще ничего а Маша номер семь все 14',
#  'надо было написать что-нибудь такое для быстрого',
#  'с этим проблемы в плохом качестве есть арт Он у меня в вк в альбоме с СТ лежит',
#  'бы не хотели утром в туалет .. мы бы спали вечно D http',
#  'ArmenPavlovich сама по себе таких рамок дурацкая обычные мне больше нравились Такие у меня потрескались',
#  'Больше не буду постить Такеру а то вы все тоже начнете его любить х',
#  'RT s_bezrukov Репетируем не перестаем готовимся Премьера 22 Приходите и оцените плоды наших усилий',
#  'Сегодня важный день такие редко у меня бывают доброеутро',
#  'RT vadebiwesada Hello world Пока писать нечего но идея однозначна здравая Я уже писал в жэжэ',
#  'Так хотелось еще дальше переписывается но я думаю не стоит',
#  'В Яндекс.Календарь есть список дел ... Но он неудобнее чем Задачи в Google ...',
#  'Koloradsky ммм надо подумать Еду загорать в июле на море яйца в кучку улыбку на лицо',
#  'Зачем в твиттере под чужим именем писать хуйню а ты в лицо подойди скажи слабо что-ли Многие поймут о ком я',
#  'prisonero_o как ты как ты как ты все мне рассказывай',
#  'И опять отправка письма по привычке ... И мои душевные ушли не туда',
#  'Всё отлично разнесу всё к хуям Настя я еду DD',
#  'ОН ГОТОВИТ СЕРЬЕЗНО',
#  'literalwolf У меня сегодня фейсбук заблокировали Я так поняла это уже пропало',
#  'Мне брат диск дал Звонок Первую часть Я очень хочу посмотреть но уроки и дома все так не люблю',
#  'Мне кажется я как маньяк блин какой то',
#  'Упоротый момент ... Хулиган http',
#  'Kristino4ka_M посмотри короч у него D я теперь ленту читать не хочу хахаахах',
#  'RT mormorarmy да-да я когда увидела это то сразу увидела себя в будущем D',
#  'niukku_barker на нг тогда поговорим Но это собаки у меня очень ревнивы',
#  'я каэш по работе не особо делать а вот то что от души бесплатно за милую душу и даже книга про эффективность не поможет',
#  'Привет как ты Слушай ты в центре города будешь в ближайшие дни Я должен тебе отдать диск',
#  'поехала за рубашкой в которая мне понравилась приезжаю вроде как размер мой иду она мне большая а она мужская оказалась',
#  'Ты твердил что тебе на меня пофиг что ж ты так удивился увидев меня со своим лучшим другом FOLLOW',
#  'kkdrogersdcs Горячий чай в этот пасмурный осенний день великолепен А я грущу',
#  'zdelirium ох Зарина Зарина мне кажется всем сложно выбирать подарки а мне особенно моя фантазия на самом дне никогда не знаю что нужно',
#  'RT Как же заебало что я заебался заебываться',
#  'дааа я сегодня прыгала от счастья -D спасибки Женёк',
#  'Suicide_Mitch_ fluttershyyyyy ну и лан',
#  'пиво_О тёплое .. выветреное .. вымоченное из тряпки слизывать со стола ... -Не вОпрос канеш буду http',
#  'Никто не хочет дарить мне белую елку Я негодую',
#  'эту неделю должны были теплые моменты обнимашки и поцелуйчики но почему-то не вышло перестала я верить в чудо ..',
#  'RT внезапно узнал об дома сервак и пусть оно себе работает буду торренты качать а вообще и',
#  'RT Сегодня был день одновременно и офигенный и ужасный',
#  '_Saturana_ эх ... тяжко тебе я на работе работаю ... и кушаю :3',
#  "DominoBank За его в `` Даун '' готов простить ему даже такую глупость В душе ведь он бля добрый Чё не опять не то сказал",
#  '`` вещи у парня должны быть шикарными характер голос парфюм и самое главное брюнетка `` Некоторым блондинки больше подходят',
#  'Меня оставили на целый день с сестрой .. Что за несправедливость Я хочу гуляяять даже сериал посмотреть не могу блин',
#  "lesakrim Да я видела я хотела орать `` ты умничка '' но всеровно не б было",
#  'BayarsaihanG Та нээрээ үнэн юмаа',
#  'вообще никогда не понимала зачем люди это делают пукан так почему бы и да',
#  'RT sugujosezem предлагаю признать лучшим камуфляжем для бойца на любом ТВД близко расположенную голую молодую сочную девушку',
#  'RT obnuli этот дурацкий момент когда ты идёшь по улице и начинаешь улыбаться как придурок вспомнив что-то',
#  'Витя сначала дал мне надежду а потом сам же её и убил',
#  'Пришел к девушке домой а у неё там стоит линукс и неплохая акустика хм может это не девушка',
#  'Но настроения так и не появилось',
#  'сижу под дверью на полу жду свою очередь на зачёт по истории мирового театра',
#  'Mr_King_Of_Swag мне кажется это приложение удалили и по отдельности написала Вк и плэйлист все равно не то http',
#  'your_countess это да ... просто стремно просто так репы ты думаешь мы за месяц его ..... я что-то очень сомневаюсь',
#  'а сча мне ужасно болит живот по идее желудок но я ж поела',
#  'Кто нибудь погуляйте с На улице слишком холодно .... и меня жутко морозит',
#  '« Джек Райан Теория хаоса » Международный трейлер №4 http kinopoisk Пара новых кадров с Крисом но не с',
#  'Manya_Khitraya А вот есть-то я их не буду',
#  'Джа 0-1 счет в пользу моряков',
#  "jul_sazonova Абсолютно так Типа `` компенсация за ''",
#  'RT _Rock_Damn_ Stoned1111 СУК ХУЛИ ТЫ МЕНЯ ТА D Я НИ ХОЧУ УМИРАТЬ',
#  'RT SugarPony23 li2nka_666 Ууу Плак плак',
#  'Красавчики мне понравились даже немного больше чем Элтон ...',
#  'MarcusSlytherin да бедный он он ими не часто питается министерство его',
#  'До Нового Года и маминого дня Рождения 9 дней а еще не придумала ей подарок',
#  'Ekolga печаль мне надо завтра быть бодрячком а я не знаю что и придумать',
#  'Вроде со всеми помирилась Ну вернее кто этого хотел',
#  'aavst День рожденья грустный праздник ты улыбнись виски спроси не грусти напрасно',
# ...
#  'RT olyakeehl arzlinos не могу уйти завтракать ахах только грушу съела пока что mtvstars 30 Seconds To Mars',
#  'E6aPbTeppopucT пусть бомжи сделают тебе подарок и выйдут в ЛЧ',
#  'А завтра идем на Вот там оторвемся наверное ахах',
#  'Что то одна фигня вокруг к кому не зайди что происходит блин',
#  'RT xenia_sobchak Сережа Полонский прислал мне фото из камбоджийской тюрьмы ... http //t.co/vsvXBUP3Bb',
#  "bcex_b_pot читала из этого все кроме `` Гэтсби '' его и прочту спасибо",
#  'Внимание ненормативная лексика и ОГРОМНОЕ РАЗРЕШЕНИЕ',
#  'Alex7236 IvanKnyazev1 Возможно чистота и красок http',
#  'поч в близких по духу хуйня где мои',
#  'Бедный Саймон опять болеет так жалко его',
#  'Проснулась Кашель жуткий Бесит меня это А так все хорошо',
#  'сук я ответ на вопросик строчила а там англ раскладка была',
#  'Фуфуфу Мне одной снятся сны с участием сатаны и ада',
#  'получила визу в UK урааа теперь только осталось заработать оценки',
#  'blinov001 не пустили Сашу в мп мы и скоро напишем наши',
#  'убегаю и плачу ... это инвестиции меня таким делают я не понимаю нихуя',
#  'Фотография с лета ностальгия http',
#  'Погода продолжает радовать снегом и светом http',
#  'больше всего мне на линуксе не хватает 3-х вещей фотошопа айтюнса и лингво ...',
#  'RT kot_kokc Helga__Russia отлично проснулся недавно А ты как',
#  '`` некуда просто -__-',
#  'RT Мальчики девочки А кто есть недалеко от садовой-самотечной д.1 Надо машину прикурить спасите-помогите ла',
#  'RT lentaruofficial припекло',
#  'RT vesna_sm gruppa_GS признавайтесь ваших рук дело уж больно шрифт на ваш похож http //t.co/lM2Ab4qfpH',
#  'RT Моя Аня в Москве А встретиться не получится',
#  'RT TakanoriMitsuki привеееет с добрым утром',
#  'Хожу лечиться в поликлинику на ... но позвоночник все равно болит',
#  'Мама любит порадовать дочу http',
#  'У нас с Любой сейчас в тренде Бэтмен Весь день его зовем D мынормальные',
#  'весь день ничего не жрать а вечером в себя порцию слона в моем стиле А ПОТОМ О НЕТ Я ЖИРНАЯ ЖИРНАЯ ЖИРНАЯ',
#  'До вторника нормальный интернет Я буду скучать',
#  'RT прошлую зиму ... ехх ... как ио и хорошо было .. и с родителями не .. а',
#  'да у меня все скучно и еще и не выспалась',
#  'конечно всякие пью таблеткам травлюсь Как утро в школе прошло',
#  'из этой психушки до самого вечера Хотя бы вечер понедельника принесет что-то приятное',
#  'все заболели этим фильмом меня вот заинтриговал даже и я теперь жду',
#  'А я же забыла сказать что наконец сходила на ГИ меня нужно держать подальше от семейства ну',
#  'RT mariagula01 КАКОЙ НЕ ТЫ ^^',
#  'Папа подсадил меня на Scorpions Теперь слушаем их песни на пару',
#  'Блиииин как стыдно забыла Руслана вчера поздравить Только сейчас вспомнила что вчера 14 было',
#  'RT смотрит на вас как на И странно при этом',
#  'RT v_khabarov alej_ramoni у меня в Машине такая же',
#  'Порадовала реклама вконтакте не осуждаю просто ржу http',
#  'ChizhYana Appolinariua1 я знаю как бы он с дождиком в классе и с тобой',
#  'и вообще по-любому от меня не Коза',
#  'красный дым идет Или колбасой пахнет',
#  'я боюсь что все-таки сорвусь и сделаю тату на пальцах',
#  'а вот мои первые 3 правда вас здесь нет вы же мне не пишите http',
#  'ничто так не угрожает планете как мысли человека',
#  'Почему нельзя вернуть то что было .. Т__т .. теперь всё это останется лишь на фото .... которые никто не увидит ....',
#  'doktortwiters кто вот будет тушить во мне пожар то',
#  "davletkildeeva Хорошее название для `` День в жопе сурка '' доброе утро и вам Сима",
#  'RT bank_rs Идеи в какие города мира Олимпиаду до Сочи можно отправиться в отпуск или на уик-энд http',
#  'чего нет того нет http',
#  'Что делать если 14 матан а я ничего не знаю',
#  'YOLTERBIEBERA волтер с днем рождения любимый множество встреч с джастином тебе я люблю тебя милый з',
#  'сейчас буду смотреть САМУЮ САМУЮ ПОСЛЕДНЮЮ СЕРИЮ',
#  'RT Dinko1999_ а что нам приносит сердце сосуды Ахаха для нашего класса это норма',
#  'bella_podgorn я тоже заболела но знаешь сегодня 13 пятница и обычно у меня это хороший день а сегодня все контрольные провалила',
#  'спасибо как раз думала что посмотреть',
#  'olhowick весь мир ездит посмотреть на эти',
#  'теперь я буду знать что макеев побил я в конце недели все серии смотрю',
#  'Первый счастливый понедельник за последнее время вместо пар с утра в зал и весь день предоставлен только мне Вот оно счастье',
#  "Читаю `` комбинированные съемки '' как `` комбинированные семки '' бляяя кароч все плохо 00 0 000",
#  'балин деньги закончились на мобиле хорошо хоть сижу с компа',
#  'Мастер машинку D http',
#  'RT Alex_Sparrow_ Lastnight 3 часа ночи Кучу треков надо доделывать А мы с братаном egorkreed джемим http //t.co/Ue792BAPQI',
#  'Алкоголь до 21 года не продают .. ты что то путаешь',
#  'ноги болят компресс хоть как-то эту боль',
#  'заигрался ........... http',
#  '“ Urangoo_A TuulBS За тэгүүл шинэ жил дээр миний өмнөөс ”',
#  'Гулять невыносимо такой дубак на улице http',
#  'несомненно зеленых или синих не будет явно детей',
#  'RT my_drag_is_rock я съел бутерброд и теперь я толстый оч чего делаешь с',
#  'Опиши мене за допомогою 5 слів= — маленька симпатична кароока приємна http',
#  'у меня вот так же легла в 6 встала в 9',
#  'славу богу что без температуры ты',
#  'Ко мне приходили нежданные гости Хоть они и нежданные мне было приятно их видеть',
#  'RT kivicakicir http Скажите пожалуйста как у человека может быть 1000 одноклассников O_o',
#  'не хочу чтоб ты уезжал с тобой хочу но нельзя',
#  'RT 95Shevchenko',
#  'dmitry_alex1 А я и не сам не плошай А ты хотел бы увидеть меня Посмотри в ЛС ^_^',
#  'ты патаму шта мой ниче не смотри D',
#  "`` он же вылитый '' Фото http",
#  'RT SFGO76 tovarish_sukhov shulz19761 FTYSp Я сейчас слушаю и превращаюсь в ..',
#  'RT VadimKovalev Коллеги сегодня я вас всех собрал потому что вы пазл',
#  'Вот и закончились Мониторинги http',
#  'vboshke RebelLoveSongs я решил остановиться на этом год назад',
#  'RT HollyDniwe ЧЕТВЕРКА ИЗ МЕНЯ и лавке вас 0 0 http',
#  'SomePadAckles ну нахрена так писать 9 9',
#  'тортик кремом вниз угадайте откуда у меня растут руки',
#  "RuFoteev Sofa_Zelik nalbakrinova Еще как противно Особенно в а рядом `` нечто '' ... А Простите ...",
#  "Жесть о_О `` infomoscow24 С 1 января билет на одну поездку в метро будет стоить 40 рублей на две – 80 Такая вот радостная новость ''",
#  'over__again я нормально но устаю сильно в школе я бы тоже просидела ахаз',
#  'Заяш коза разбудила блять Ну зачем ты так делаешь',
#  'поднимаю взгляд и наблюдаю кипу комиксов теперь это модно сука',
#  'Нифига себе ахахах я хожу два раза в неделю',
#  'Alex_Shvarz Саша вашего наверное Я вот в РФ живу и ОН не МОЙ президент Не',
#  'Завтра в школу не хочу хочу новый год',
#  'с утра мало народу везуха тебе бляя к концу дня народу',
#  '2035988969 Во как все запутано .. сразу и не',
#  'RT CatMoriz Mandrara Так всегда с украинскими мамами любой суп превращается в борщ',
#  '.. я сожрала 2 куска 15 мин 1 на время ...... началась надо чем нибудь запить',
#  'включая посе русские песни складывается ощущение что ты сейчас был в бах и реальность в общем странное и неловкое чувство',
#  'RT otutuxuhal Так вот ты какая неведомая еб ная ху ня ... о_О http //t.co/NBMtJwe3ID',
#  'Так интересно Люди куда-то отдыхают путешествуют открывают для себя что-то новое',
#  'блин начинаются тренировки ооо боже мой',
#  'RT Проводили мое брата на поезд',
#  'RT CoolAnyta00 а http',
#  'питерский факс не дружит с',
#  '123ulya тебе лишь бы',
#  'Весело кіно а погуляли Дякую',
#  'RT dedmorozrus Здраствуй Дедушка Мороз борода из ваты Подари на Новый год BMW P.S Я себя вел хорошо',
#  'просто группа закрыта а меня там нет поэтому не посмотреть поподробней но надеюсь я все верно теперь знаю спасибо',
#  'хочу ... хочу хочу хочу то что так долго снится',
#  'бл я же 99 99',
#  'Kristina_Pan почему Все же не может быть так плохо',
#  'RT sijetokixuze Меня бесит писать сочинения по инглишу на тупые темы',
#  'хочу себе айфон только из за',
#  'Сегодня в универе благотворительная ярмарка Факультет менеджмента НИУ ВШЭ http //t.co/ZIQEznNaCP',
#  "Только если сессию сдам Тогда помогу А так только текст обработать И то будет проблематично с моим русским -_- ''",
#  'Silya65 yanacowperwood Иди учи историю блин',
#  'Если объявят траур то будет еще один терракт теперь на ОТС .... Сегодня вот работать в лучшем случае до 23 в худшем до 2',
#  'Чему бы грабли не учили а сердце верит в',
#  'RT CheeseInTheDark больше нет смысла смотреть аниме',
#  'Кто бы знал как я устал но я еще не закончил уборку',
#  'RT xadodigyh Странная штука жизнь вроде затрахала а не удовлетворяет 0 http',
#  'не искушай меня мне нужно сдать анатомию',
#  'corristo я слушаю всё подряд мне нравится вообще вся музыка в',
#  "Называть `` '' придумал `` советский '' Придумал но как-то не пошло",
#  'fedorov_den я прямо завидую тебе я не выспалась',
#  'тогда желаю я ушел ... делами удачки 3',
#  'RT Katrina_Vintur Дед Мороз ну пожалуйста http',
#  'Сегодня ужин выглядит так http',
#  'RT это так кайфово просыпаться с любимым тебе человеком Я каждому желаю такое почувствовать З',
#  'hair теперь ясно что если сначала 3 см то дальше пока будут подравнивать ещё',
#  'svegrrrr не играла чувствую что подзабыла аж',
#  'RT Dr_Anuudari Гангалахыг мэддэг мертлее арчилахыг мэддэггуй евдеж мэддэг мертлее сэргийлж мэддэггvй',
#  'Ну збс я опять ты так хорошо слушаешь',
#  'Болеть так вместе http',
#  'Хотя многие пытаются http',
#  'Попала под домашний арест ... Теперь неделю дома сидеть придётся',
#  'RT А у меня даже елки нет',
#  'Скоро я буду свободееееен Надо бы к сессии начать готовиться что ли ..',
#  'Очень понравилась вчерашняя поездка в Москву http',
#  'А реклама кока колы вообще теряет свои позиции',
#  'Надо пересилить себя и всё же сходить на физкультуру',
#  'arianagranqe камин и налил горячий шоколад D',
#  'Я надеюсь он живой вроде сам в машину скорой заходил',
#  'Даже собак сегодня не http',
#  'я сейчас расплачусь тупой тупой день',
#  'Я тебя видела а ты меня не узнала',
#  'почему я узнаю что у андерсона новый фильм из тумблера хочу в кино и в оригинале',
#  'RT пусть дима мне поможет завтра',
#  'Компоненты можно изучать методом тыка Так даже интереснее',
#  'сижу время без 15 шесть утра моя зайка красится в 6 30 в в военкомат не хочу .....',
#  'у меня такое дикое желание макароны на потолок',
#  'NadushaTsi ахах нет я имею в виду если бы я на месте Нади была так бы поступила',
#  'RT sleepy_creature листаю ленту смотрю какой-то левый чувак юп не знакомый ... позде понял что это я',
#  'и спросил ты есть вк а я сказала что нет я дура мальчик симпотичный был',
#  'vla_da Ну или изначально массово шли С тех пор у меня стереотип А вообще для меня это зимнее видео Сидишь смотришь',
#  'Очень жаль что сразу не разглядела в тебе этого Очень Не люблю разочаровываться в людях но иногда все таки приходится',
#  'Йа конечно извиняюсь но в этом году №1 в был даже у фобов а у тока №5 какой позор На весь район на весь район хддд',
#  'Yess27os YevloRoost просто по и жить скучно вот и нюансы случаются',
#  'Как я угадала а D Вот-вот Сейчас еще новогодняя суматоха .. ждать мне пол года х3',
#  'Не знаю что делать беда Второй день подряд тыкаю котика розовыми в его же говно начал какать в коридоре Есть другие идеи',
#  'болезнь — это же фактически маразм но маразм звучит както мягче',
#  'musiklove1 старый твиттер полетел к матери тепер новый спасибо',
#  'На работе .. http',
#  'да я слышала что-то потому и сомневаюсь Но там где я сейчас тоже плохо',
#  'наверняка очередная техническая шняга какая-нибудь тока хз кто может зарядить на разбор сейчас',
#  'Продолжение к тому посту а через 7 минут стало Узнаю родного',
#  'yprt_olen _street_artist ОСТАЛОСЬ НАЙТИ ХАТУ D',
#  'Игровые новинки Вышла легендарная игра GTA San Andreas для iPhone и iPad игры',
#  'День от дня не легче опять влипла http',
#  'не хошь вернуться к истокам у нас лучше чем и металл',
#  'Мороз отжёг конечно в Самаре Но кстати как-то неудивительно',
#  'что никто не знает где продается',
#  'почему-то совсем нет новогоднего настроения ..',
#  'adelichka_chudo что у вас тут за планы такие включите в лист в следующий раз Давайте провожу в аэропорт',
#  'я даже по школе соскучилась но вставать так рано блин',
#  'Ой да мне срать что у меня с рукой главное завтра в город поехать',
#  'RT Milda282 jstoruser уж не знаю кто вас сумел настолько что вы не понимаете разницы между событиями в Москве и Киеве',
#  'kuzma_skryabin Приходите пожалуйста нам вас не хватает у вас прекрасное чувство юмора а это то что сильнее многого',
#  'Как избавиться от ночного кашля Блять меня уже от него выворачивает',
#  'mamamaxima што же я дурь не а ведь была мысль',
#  'он всем идет так мне стричься прям под длинное но мама хер даст так подстричься А бесят',
#  'Поэтому вот вам плюшевый котик он очень мимими за то время что он у меня был я его полюбил http',
#  "а я то думала ты мне на тельчик `` Голодные игры '' 99",
#  'RT Komanda_Khimki IrekVildanov Bagira_02 а к Миши тоже есть голова',
#  'свела меня с ума ну так останься рядом',
#  'ksu_bo спасибо моя любимая подружка только я буду сидеть на первой парте и отвечать ему в лицо уже через 45 минут',
#  'изменщик',
#  'GalyamovaElinka Ахахахха доставала наверно своими',
#  'про то что он я не догадывалась не разузнала этот вопрос и болезни рано',
#  'RT hudeweje Привет Sony Блин ну почему реплики говорят другие Про Бога у спрашивала а не священник по ход',
#  'RT принтер http',
#  'чувство собственного зашкаливает',
#  'получил приглашение на mail.ua отправлял запрос где то полгода назад',
#  'RT o_OLETO делаешь',
#  'ой блян ты что так .. лечишься',
#  'Ой мамочки как же правда надоел этот ремонт за стенкой вторую неделю уже покоя нет все стены они там сносят что хоть по ...',
#  'Зейн писал песни для девушки когда ему было 13 лет так мило',
#  'Мы с таней криминал D руку оторвали DD http',
#  'Два года отношения к пользователям и только один отрицательный отзыв Ну как так-то Это же скучно еда',
#  'RT m0tl Кстати я начал читать когда это еще не стало',
#  "Спасибо тебе парень из Макси Ты мой день этим молоком `` на день раньше '' которое с",
#  'RT katyakatya1996 Тренировка отменяется Вот обида',
#  'Хочу скачать книгу но не могу найти ... Помогите',
#  'RT Ужасно скучаю по любимым Так давно не',
#  'Кошмар время пол 4 я только глаза открыла',
#  'Сегодня снежинок http',
#  'RT ju_inspired печально немного http',
#  'Приехал на работу пол 4го вот это я понимаю рабочий день',
#  'more__moe давай на следующей неделе можно вечером во вторник или четверг или на выходных',
#  "foreveryoungmnk ну тогда просто представь что ты один .. можешь соорудить на полу любой из комнат и `` уйти из дома '' D",
#  'Ну да когда Стим голову ебет это больше напрягает чем не сданный экзамен',
#  '“ hot_fact Бархатный Ferrari на улицах Лондона http ” такого еще не видела',
#  'RT Xiongmao_Tao exocometorussia короче теперь всё от нашей активности зависит',
#  'RT iHazza69 adina0612 неа у меня на комп ограничение Мне только пол часа в день сидеть можно',
#  'Но биатлон я всё-таки люблю больше',
#  'день катка походу D еще другие люди зовут на каток',
#  "За два `` проглотил '' книгу `` из клуба '' Не самая его лучшая книга http",
#  'Очень красивый зверь Моя мечта http',
#  'до нового года 8 дней а я только брату подарок купила',
#  'на каток хочется а у Саши с коньками чего то случилось',
#  'сделала все уроки кроме химии ибо я не знаю что задавали',
#  'bugagashenkaya Викуль ты иногда не понимаешь моих шуток Я же понимаю что у тебя конечно же я смех',
#  'Увидела сегодня Лизу __ Так скучала по ней Мне не хватало её обнимашек',
#  "В общем я уже все придумала И это должно смотреться очень круто Зачем `` я сопли по лицу размазывала '' не понимаю",
#  'ну или старый Я сверху мотивацией',
#  'RT PsykerO1477 Какой незаметный оказался праздник',
#  'бедные мои ногиии ещё опять начали болеть вот я лох',
#  'А еще сегодня была очередная красивая дата 11.12.13 но она для меня ничего не значит А вот та что завтра ...',
#  'RT Aleks_SPb Бабушка лучше Тебе и не знать что наш чиновник Сечин получает 138.000.000 миллионов рублей в месяц http //t.co/SAeZsI6koz',
#  "RT 4ifra на `` Одноклассниках '' комментируют Да кому ты нужна лахудра http //t.co/kFVEeOfxuA",
#  'RT А крутой descamp получился прошлогодний был не хуже а этот еще лучше спасибо организаторам http',
#  ...]

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize, stop_words=noise)
bow = vec.fit_transform(str_hight_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#     negative       0.79      0.77      0.78     29127
#     positive       0.76      0.79      0.78     27582
#
#     accuracy                           0.78     56709
#    macro avg       0.78      0.78      0.78     56709
# weighted avg       0.78      0.78      0.78     56709

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize, stop_words=noise)
bow = vec.fit_transform(str_medium_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['``'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
#               precision    recall  f1-score   support
#
#     negative       0.50      0.53      0.52     26314
#     positive       0.57      0.54      0.55     30395
#
#     accuracy                           0.54     56709
#    macro avg       0.54      0.54      0.53     56709
# weighted avg       0.54      0.54      0.54     56709

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize, stop_words=noise)
bow = vec.fit_transform(str_low_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['``'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
#               precision    recall  f1-score   support
#
#     negative       0.45      0.55      0.49     23060
#     positive       0.63      0.54      0.58     33649
#
#     accuracy                           0.54     56709
#    macro avg       0.54      0.54      0.54     56709
# weighted avg       0.56      0.54      0.55     56709

# %% [markdown]
# ## О важности эксплоративного анализа
#
# Но иногда пунктуация бывает и не шумом -- главное отталкиваться от задачи. Что будет если вообще не убирать пунктуацию?

# %%
vec = TfidfVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize)
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14044/3893711724.py in <module>
#       1 vec = TfidfVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize)
# ----> 2 bow = vec.fit_transform(x_train)
#       3 clf = LogisticRegression(random_state=42)
#       4 clf.fit(bow, y_train)
#       5 pred = clf.predict(vec.transform(x_test))
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1844         """
#    1845         self._check_params()
# -> 1846         X = super().fit_transform(raw_documents)
#    1847         self._tfidf.fit(X)
#    1848         # X is already a transformed view of raw_documents so
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1200         max_features = self.max_features
#    1201
# -> 1202         vocabulary, X = self._count_vocab(raw_documents,
#    1203                                           self.fixed_vocabulary_)
#    1204
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1112         for doc in raw_documents:
#    1113             feature_counter = {}
# -> 1114             for feature in analyze(doc):
#    1115                 try:
#    1116                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     104             doc = preprocessor(doc)
#     105         if tokenizer is not None:
# --> 106             doc = tokenizer(doc)
#     107         if ngrams is not None:
#     108             if stop_words is not None:
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     128     """
#     129     sentences = [text] if preserve_line else sent_tokenize(text, language)
# --> 130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\__init__.py in <listcomp>(.0)
#     129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
# --> 131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# ~\Anaconda3\lib\site-packages\nltk\tokenize\destructive.py in tokenize(self, text, convert_parentheses, return_str)
#     116
#     117         for regexp, substitution in self.PUNCTUATION:
# --> 118             text = regexp.sub(substitution, text)
#     119
#     120         # Handles parentheses.
#
# KeyboardInterrupt:

# %% [markdown]
# Шок! Стоило оставить пунктуацию -- и все метрики равны 1. Как это получилось? Среди неё были очень значимые токены (как вы думаете, какие?). Найдите фичи с самыми большими коэффициэнтами:

# %% [markdown]
# ## Задание 2.
#
# найти фичи с наибольшей значимостью, и вывести их

# %%
punktuation_text = []
for stroka in df.text:
    punktuation_text.append([token for token in stroka.split() if token in punctuation])
punktuation_text
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['.'],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@'],
#  ['!', '!'],
#  [],
#  [],
#  [],
#  ['-'],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['.', '-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', '-', '-', '-'],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [')', '-', ')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['/', ')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['.', ',', ','],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['='],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@'],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  [],
#  [')', ')'],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [','],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  ['-'],
#  [',', ')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  ['-'],
#  ['/'],
#  [],
#  [],
#  [],
#  [],
#  [')', '@'],
#  [':'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['?'],
#  ['@'],
#  ['/'],
#  [')'],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@'],
#  [],
#  [],
#  ['"'],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [':'],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['?'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [':', '!', ',', '?'],
#  [],
#  [],
#  ['-', '-'],
#  [')', '-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['?'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  ['?'],
#  [],
#  [],
#  [],
#  ['@'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', '-', '-'],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', '-'],
#  [],
#  [],
#  [':'],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['/', '/'],
#  [],
#  [','],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['/', '?'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"', '-', '"'],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"', '"', '.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', '-'],
#  [],
#  ['-', '-', '-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', ')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  ['-', ')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"', '-', ','],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-', '-', '-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@'],
#  [],
#  ['-', '-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [','],
#  ['-'],
#  [],
#  [],
#  ['!'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['?'],
#  [],
#  [],
#  ['"'],
#  [],
#  [],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [':'],
#  [],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['?'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['@'],
#  [')'],
#  [],
#  [],
#  [','],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['"'],
#  [],
#  ['-'],
#  ['@'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['/', '/'],
#  [],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [')'],
#  [],
#  [],
#  ['-'],
#  [],
#  ['-'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
dict_punctuation_p = dict()
dict_punctuation_n = dict()
for i in punctuation:
    dict_punctuation_p[i]=0
for i in punctuation:
    dict_punctuation_n[i]=0
    
for i,val in enumerate(df.label):
    if val == 'positive':
        for punkt in punktuation_text[i]:
            if punkt in dict_punctuation_p:
                dict_punctuation_p[punkt] += 1
    else:
        for punkt in punktuation_text[i]:
            if punkt in dict_punctuation_n:
                dict_punctuation_n[punkt] += 1

# %%
dict_punctuation_p, dict_punctuation_n
# Out:
# ({'!': 408,
#   '"': 318,
#   '#': 18,
#   '$': 10,
#   '%': 17,
#   '&': 0,
#   "'": 0,
#   '(': 0,
#   ')': 3649,
#   '*': 43,
#   '+': 128,
#   ',': 2143,
#   '-': 6453,
#   '.': 488,
#   '/': 1085,
#   ':': 293,
#   ';': 21,
#   '<': 0,
#   '=': 38,
#   '>': 0,
#   '?': 399,
#   '@': 615,
#   '[': 1,
#   '\\': 0,
#   ']': 8,
#   '^': 11,
#   '_': 4,
#   '`': 0,
#   '{': 0,
#   '|': 46,
#   '}': 0,
#   '~': 14},
#  {'!': 316,
#   '"': 137,
#   '#': 15,
#   '$': 7,
#   '%': 16,
#   '&': 0,
#   "'": 0,
#   '(': 5300,
#   ')': 0,
#   '*': 25,
#   '+': 99,
#   ',': 2413,
#   '-': 3892,
#   '.': 511,
#   '/': 385,
#   ':': 404,
#   ';': 42,
#   '<': 0,
#   '=': 24,
#   '>': 0,
#   '?': 362,
#   '@': 162,
#   '[': 1,
#   '\\': 0,
#   ']': 12,
#   '^': 5,
#   '_': 9,
#   '`': 0,
#   '{': 0,
#   '|': 35,
#   '}': 0,
#   '~': 19})

# %% [markdown]
# Посмотрим, как один из супер-значительных токенов справится с классификацией безо всякого машинного обучения:

# %%
cool_token = ')'
pred = ['positive' if cool_token in tweet else 'negative' for tweet in x_test]
print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       1.00      0.85      0.92     33049
#     positive       0.83      1.00      0.91     23660
#
#     accuracy                           0.91     56709
#    macro avg       0.91      0.93      0.91     56709
# weighted avg       0.93      0.91      0.91     56709

# %% [markdown]
# ## Символьные n-граммы
#
# Теперь в качестве фичей используем, например, униграммы символов:

# %%
vec = CountVectorizer(analyzer='char', ngram_range=(1, 1))
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
#              precision    recall  f1-score   support
#
#    negative       0.99      1.00      1.00     27667
#    positive       1.00      0.99      1.00     29042
#
# avg / total       1.00      1.00      1.00     56709

# %% [markdown]
# В общем-то, теперь уже понятно, почему на этих данных здесь 1. Так или инчае, на символах классифицировать тоже можно: для некторых задач (например, для определения языка) фичи-символьные n-граммы решительно рулят.
#
# Ещё одна замечательная особенность фичей-символов: токенизация и лемматизация не нужна, можно использовать такой подход для языков, у которых нет готвых анализаторов.

# %% [markdown]
# ## Домашнее задание
#
# все материалы для выполения дз в `sem2.ipynb`
#
#
# ### Задание 1.
#
# **Задание**: обучите три классификатора:
#
# 1) на токенах с высокой частотой
#
# 2) на токенах со средней частотой
#
# 3) на токенах с низкой частотой
#
#
# Сравните полученные результаты, оцените какие токены наиболее важные для классификации.
#
#
# ### Задание 2.
#
# найти фичи с наибольшей значимостью, и вывести их
#
#
# ### Задание 3.
#
# 1) сравнить count/tf-idf/hashing векторайзеры/полносвязанную сетку (построить classification_report)
#
# 2) подобрать оптимальный размер для hashing векторайзера
#
# 3) убедиться что для сетки нет переобучения

# %%
vec = TfidfVectorizer(ngram_range=(1, 1))
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#     negative       0.73      0.77      0.75     26734
#     positive       0.78      0.75      0.77     29975
#
#     accuracy                           0.76     56709
#    macro avg       0.76      0.76      0.76     56709
# weighted avg       0.76      0.76      0.76     56709

# %%
vec = CountVectorizer(ngram_range=(1, 1), tokenizer=word_tokenize, stop_words=noise)
bow = vec.fit_transform(x_train)
clf = LogisticRegression(random_state=42)
clf.fit(bow, y_train)
pred = clf.predict(vec.transform(x_test))
print(classification_report(pred, y_test))
# Out:
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:388: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['``'] not in stop_words.
#   warnings.warn('Your stop_words may be inconsistent with '
# C:\Users\alimc\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
#               precision    recall  f1-score   support
#
#     negative       0.80      0.77      0.78     29136
#     positive       0.76      0.79      0.78     27573
#
#     accuracy                           0.78     56709
#    macro avg       0.78      0.78      0.78     56709
# weighted avg       0.78      0.78      0.78     56709

# %%
for i in range(1,5):
    from sklearn.feature_extraction.text import HashingVectorizer
    vec = HashingVectorizer(n_features = 500*i)
    bow = vec.fit_transform(x_train)
    clf = LogisticRegression(random_state=42)
    clf.fit(bow, y_train)
    pred = clf.predict(vec.transform(x_test))
    print(classification_report(pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.61      0.63      0.62     27082
#     positive       0.65      0.63      0.64     29627
#
#     accuracy                           0.63     56709
#    macro avg       0.63      0.63      0.63     56709
# weighted avg       0.63      0.63      0.63     56709
#
#               precision    recall  f1-score   support
#
#     negative       0.63      0.65      0.64     27145
#     positive       0.67      0.65      0.66     29564
#
#     accuracy                           0.65     56709
#    macro avg       0.65      0.65      0.65     56709
# weighted avg       0.65      0.65      0.65     56709
#
#               precision    recall  f1-score   support
#
#     negative       0.64      0.67      0.65     27154
#     positive       0.68      0.66      0.67     29555
#
#     accuracy                           0.66     56709
#    macro avg       0.66      0.66      0.66     56709
# weighted avg       0.66      0.66      0.66     56709
#
#               precision    recall  f1-score   support
#
#     negative       0.65      0.67      0.66     27255
#     positive       0.69      0.67      0.68     29454
#
#     accuracy                           0.67     56709
#    macro avg       0.67      0.67      0.67     56709
# weighted avg       0.67      0.67      0.67     56709
